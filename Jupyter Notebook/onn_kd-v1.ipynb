# %% [markdown]
# #   0 enviorment and data setup

# %%
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models
import os
import glob
import cv2
import tqdm

# %%
import torch
input = torch.ones([1,256,3,1,10,10])
kernel1 = torch.ones([1,256,3,32,10,10])
# kernel2 = torch.ones([1,32,64,10,10])
# kernel3 = torch.ones([1,64,256,10,10])

process1= torch.mul(input,kernel1)
# process2 = torch.mul(process1,kernel2)
# process3 = torch.mul(process2,kernel3)

# %%
'''lacation for data'''
from google.colab import drive
drive.mount('/content/drive')
BASE_PATH = '/content/drive/My Drive/high10'
# Out:
# Mounted at /content/drive

# %%
import os
if not os.path.exists('/content/train'):
  # !tar --exclude='._*' -xvf /content/drive/My\ Drive/high10/hightrain.tar
if not os.path.exists('/content/test'):
  # !tar --exclude='._*' -xvf /content/drive/My\ Drive/high10/hightest.tar
if os.path.exists('/content/test') & os.path.exists('/content/train'):
  print("all done")
# Out:
# Streaming output truncated to the last 5000 lines.
# train/6/n07746186_3586.JPEG
# train/6/n07746186_5844.JPEG
# train/6/n07746186_6291.JPEG
# train/6/n07746186_15760.JPEG
# train/6/n07746186_5147.JPEG
# train/6/n07746186_3247.JPEG
# train/6/n07746186_4078.JPEG
# train/6/n07746186_1295.JPEG
# train/6/n07746186_5686.JPEG
# train/6/n07746186_2513.JPEG
# train/6/n07746186_4644.JPEG
# train/6/n07746186_14599.JPEG
# train/6/n07746186_14433.JPEG
# train/6/n07746186_3882.JPEG
# train/6/n07746186_4701.JPEG
# train/6/n07746186_4146.JPEG
# train/6/n07746186_15873.JPEG
# train/6/n07746186_195.JPEG
# train/6/n07746186_2092.JPEG
# train/6/n07746186_7785.JPEG
# train/6/n07746186_4003.JPEG
# train/6/n07746186_13362.JPEG
# train/6/n07746186_1128.JPEG
# train/6/n07746186_1082.JPEG
# train/6/n07746186_3400.JPEG
# train/6/n07746186_746.JPEG
# train/6/n07746186_12748.JPEG
# train/6/n07746186_1256.JPEG
# train/6/n07746186_11922.JPEG
# train/6/n07746186_11021.JPEG
# train/6/n07746186_12174.JPEG
# train/6/n07746186_3142.JPEG
# train/6/n07746186_204.JPEG
# train/6/n07746186_6205.JPEG
# train/6/n07746186_10763.JPEG
# train/6/n07746186_8827.JPEG
# train/6/n07746186_8574.JPEG
# train/6/n07746186_2315.JPEG
# train/6/n07746186_12861.JPEG
# train/6/n07746186_13289.JPEG
# train/6/n07746186_6706.JPEG
# train/6/n07746186_3103.JPEG
# train/6/n07746186_1978.JPEG
# train/6/n07746186_5192.JPEG
# train/6/n07746186_2657.JPEG
# train/6/n07746186_15392.JPEG
# train/6/n07746186_16044.JPEG
# train/6/n07746186_14429.JPEG
# train/6/n07746186_10939.JPEG
# train/6/n07746186_3877.JPEG
# train/6/n07746186_1149.JPEG
# train/6/n07746186_12142.JPEG
# train/6/n07746186_9200.JPEG
# train/6/n07746186_4062.JPEG
# train/6/n07746186_9191.JPEG
# train/6/n07746186_11739.JPEG
# train/6/n07746186_6008.JPEG
# train/6/n07746186_15146.JPEG
# train/6/n07746186_10581.JPEG
# train/6/n07746186_14468.JPEG
# train/6/n07746186_11390.JPEG
# train/6/n07746186_2724.JPEG
# train/6/n07746186_15296.JPEG
# train/6/n07746186_11955.JPEG
# train/6/n07746186_1364.JPEG
# train/6/n07746186_11543.JPEG
# train/6/n07746186_11797.JPEG
# train/6/n07746186_15384.JPEG
# train/6/n07746186_7121.JPEG
# train/6/n07746186_13179.JPEG
# train/6/n07746186_5720.JPEG
# train/6/n07746186_14346.JPEG
# train/6/n07746186_15107.JPEG
# train/6/n07746186_1299.JPEG
# train/6/n07746186_1574.JPEG
# train/6/n07746186_14852.JPEG
# train/6/n07746186_13694.JPEG
# train/6/n07746186_5022.JPEG
# train/6/n07746186_4633.JPEG
# train/6/n07746186_18037.JPEG
# train/6/n07746186_930.JPEG
# train/6/n07746186_6177.JPEG
# train/6/n07746186_3230.JPEG
# train/6/n07746186_13047.JPEG
# train/6/n07746186_9113.JPEG
# train/6/n07746186_1523.JPEG
# train/6/n07746186_11492.JPEG
# train/6/n07746186_9555.JPEG
# train/6/n07746186_5576.JPEG
# train/6/n07746186_10016.JPEG
# train/6/n07746186_16341.JPEG
# train/6/n07746186_2175.JPEG
# train/6/n07746186_15428.JPEG
# train/6/n07746186_2460.JPEG
# train/6/n07746186_2030.JPEG
# train/6/n07746186_13456.JPEG
# train/6/n07746186_5872.JPEG
# train/6/n07746186_4275.JPEG
# train/6/n07746186_12586.JPEG
# train/6/n07746186_9294.JPEG
# train/6/n07746186_18308.JPEG
# train/6/n07746186_12705.JPEG
# train/6/n07746186_2572.JPEG
# train/6/n07746186_5258.JPEG
# train/7/n04373704_2532.JPEG
# train/7/n04373704_640.JPEG
# train/7/n04373704_355.JPEG
# train/7/n04373704_1871.JPEG
# train/7/n04373704_990.JPEG
# train/7/n04373704_2565.JPEG
# train/7/n04373704_2836.JPEG
# train/7/n04373704_752.JPEG
# train/7/n04373704_2420.JPEG
# train/7/n04373704_928.JPEG
# train/7/n04373704_1826.JPEG
# train/7/n04373704_2359.JPEG
# train/7/n04373704_181.JPEG
# train/7/n04373704_1430.JPEG
# train/7/n04373704_251.JPEG
# train/7/n04373704_314.JPEG
# train/7/n04373704_2965.JPEG
# train/7/n04373704_4331.JPEG
# train/7/n04373704_2524.JPEG
# train/7/n04373704_206.JPEG
# train/7/n04373704_2877.JPEG
# train/7/n04373704_1758.JPEG
# train/7/n04373704_2932.JPEG
# train/7/n04373704_969.JPEG
# train/7/n04373704_1534.JPEG
# train/7/n04373704_1236.JPEG
# train/7/n04373704_338.JPEG
# train/7/n04373704_4872.JPEG
# train/7/n04373704_1723.JPEG
# train/7/n04373704_2699.JPEG
# train/7/n04373704_1324.JPEG
# train/7/n04373704_33.JPEG
# train/7/n04373704_2508.JPEG
# train/7/n04373704_2158.JPEG
# train/7/n04373704_800.JPEG
# train/7/n04373704_2271.JPEG
# train/7/n04373704_2334.JPEG
# train/7/n04373704_945.JPEG
# train/7/n04373704_25.JPEG
# train/7/n04373704_1762.JPEG
# train/7/n04373704_5408.JPEG
# train/7/n04373704_4219.JPEG
# train/7/n04373704_3860.JPEG
# train/7/n04373704_400.JPEG
# train/7/n04373704_4921.JPEG
# train/7/n04373704_4472.JPEG
# train/7/n04373704_1670.JPEG
# train/7/n04373704_4188.JPEG
# train/7/n04373704_5326.JPEG
# train/7/n04373704_3421.JPEG
# train/7/n04373704_841.JPEG
# train/7/n04373704_457.JPEG
# train/7/n04373704_1484.JPEG
# train/7/n04373704_5097.JPEG
# train/7/n04373704_3905.JPEG
# train/7/n04373704_1938.JPEG
# train/7/n04373704_565.JPEG
# train/7/n04373704_4239.JPEG
# train/7/n04373704_836.JPEG
# train/7/n04373704_1312.JPEG
# train/7/n04373704_4956.JPEG
# train/7/n04373704_477.JPEG
# train/7/n04373704_2355.JPEG
# train/7/n04373704_924.JPEG
# train/7/n04373704_1129.JPEG
# train/7/n04373704_861.JPEG
# train/7/n04373704_162.JPEG
# train/7/n04373704_5185.JPEG
# train/7/n04373704_52.JPEG
# train/7/n04373704_1200.JPEG
# train/7/n04373704_1095.JPEG
# train/7/n04373704_2713.JPEG
# train/7/n04373704_44.JPEG
# train/7/n04373704_1703.JPEG
# train/7/n04373704_1353.JPEG
# train/7/n04373704_2314.JPEG
# train/7/n04373704_13.JPEG
# train/7/n04373704_2482.JPEG
# train/7/n04373704_1241.JPEG
# train/7/n04373704_1611.JPEG
# train/7/n04373704_1406.JPEG
# train/7/n04373704_158.JPEG
# train/7/n04373704_1543.JPEG
# train/7/n04373704_1113.JPEG
# train/7/n04373704_5296.JPEG
# train/7/n04373704_2103.JPEG
# train/7/n04373704_1902.JPEG
# train/7/n04373704_5042.JPEG
# train/7/n04373704_949.JPEG
# train/7/n04373704_1847.JPEG
# train/7/n04373704_2338.JPEG
# train/7/n04373704_2912.JPEG
# train/7/n04373704_2441.JPEG
# train/7/n04373704_363.JPEG
# train/7/n04373704_1017.JPEG
# train/7/n04373704_5054.JPEG
# train/7/n04373704_5404.JPEG
# train/7/n04373704_4079.JPEG
# train/7/n04373704_1781.JPEG
# train/7/n04373704_2841.JPEG
# train/7/n04373704_1294.JPEG
# train/7/n04373704_29.JPEG
# train/7/n04373704_2512.JPEG
# train/7/n04373704_2142.JPEG
# train/7/n04373704_1040.JPEG
# train/7/n04373704_3568.JPEG
# train/7/n04373704_4757.JPEG
# train/7/n04373704_2953.JPEG
# train/7/n04373704_91.JPEG
# train/7/n04373704_322.JPEG
# train/7/n04373704_2400.JPEG
# train/7/n04373704_637.JPEG
# train/7/n04373704_2816.JPEG
# train/7/n04373704_1387.JPEG
# train/7/n04373704_3210.JPEG
# train/7/n04373704_2114.JPEG
# train/7/n04373704_636.JPEG
# train/7/n04373704_1738.JPEG
# train/7/n04373704_1368.JPEG
# train/7/n04373704_4613.JPEG
# train/7/n04373704_1411.JPEG
# train/7/n04373704_4756.JPEG
# train/7/n04373704_2456.JPEG
# train/7/n04373704_374.JPEG
# train/7/n04373704_724.JPEG
# train/7/n04373704_1446.JPEG
# train/7/n04373704_362.JPEG
# train/7/n04373704_698.JPEG
# train/7/n04373704_2155.JPEG
# train/7/n04373704_227.JPEG
# train/7/n04373704_1283.JPEG
# train/7/n04373704_1145.JPEG
# train/7/n04373704_1515.JPEG
# train/7/n04373704_1846.JPEG
# train/7/n04373704_2293.JPEG
# train/7/n04373704_2339.JPEG
# train/7/.DS_Store
# train/7/n04373704_1391.JPEG
# train/7/n04373704_2944.JPEG
# train/7/n04373704_1684.JPEG
# train/7/n04373704_1407.JPEG
# train/7/n04373704_4605.JPEG
# train/7/n04373704_1057.JPEG
# train/7/n04373704_2694.JPEG
# train/7/n04373704_4557.JPEG
# train/7/n04373704_5346.JPEG
# train/7/n04373704_3787.JPEG
# train/7/n04373704_1493.JPEG
# train/7/n04373704_964.JPEG
# train/7/n04373704_1169.JPEG
# train/7/n04373704_1186.JPEG
# train/7/n04373704_3011.JPEG
# train/7/n04373704_2250.JPEG
# train/7/n04373704_45.JPEG
# train/7/n04373704_1702.JPEG
# train/7/n04373704_1352.JPEG
# train/7/n04373704_749.JPEG
# train/7/n04373704_175.JPEG
# train/7/n04373704_2657.JPEG
# train/7/n04373704_1978.JPEG
# train/7/n04373704_2207.JPEG
# train/7/n04373704_3046.JPEG
# train/7/n04373704_1344.JPEG
# train/7/n04373704_1714.JPEG
# train/7/n04373704_53.JPEG
# train/7/n04373704_2568.JPEG
# train/7/n04373704_5242.JPEG
# train/7/n04373704_4003.JPEG
# train/7/n04373704_3115.JPEG
# train/7/n04373704_4541.JPEG
# train/7/n04373704_2883.JPEG
# train/7/n04373704_708.JPEG
# train/7/n04373704_1939.JPEG
# train/7/n04373704_5079.JPEG
# train/7/n04373704_2246.JPEG
# train/7/n04373704_3007.JPEG
# train/7/n04373704_840.JPEG
# train/7/n04373704_3973.JPEG
# train/7/n04373704_2661.JPEG
# train/7/n04373704_1108.JPEG
# train/7/n04373704_285.JPEG
# train/7/n04373704_4473.JPEG
# train/7/n04373704_1364.JPEG
# train/7/n04373704_4536.JPEG
# train/7/n04373704_1919.JPEG
# train/7/n04373704_3027.JPEG
# train/7/n04373704_401.JPEG
# train/7/n04373704_1626.JPEG
# train/7/n04373704_2909.JPEG
# train/7/n04373704_1299.JPEG
# train/7/n04373704_4131.JPEG
# train/7/n04373704_552.JPEG
# train/7/n04373704_2765.JPEG
# train/7/n04373704_3524.JPEG
# train/7/n04373704_1325.JPEG
# train/7/n04373704_4127.JPEG
# train/7/n04373704_155.JPEG
# train/7/n04373704_1958.JPEG
# train/7/n04373704_2732.JPEG
# train/7/n04373704_440.JPEG
# train/7/n04373704_1237.JPEG
# train/7/n04373704_4035.JPEG
# train/7/n04373704_786.JPEG
# train/7/n04373704_65.JPEG
# train/7/n04373704_968.JPEG
# train/7/n04373704_1535.JPEG
# train/7/n04373704_2749.JPEG
# train/7/n04373704_1470.JPEG
# train/7/n04373704_657.JPEG
# train/7/n04373704_207.JPEG
# train/7/n04373704_3271.JPEG
# train/7/n04373704_2030.JPEG
# train/7/n04373704_342.JPEG
# train/7/n04373704_2460.JPEG
# train/7/n04373704_196.JPEG
# train/7/n04373704_529.JPEG
# train/7/n04373704_49.JPEG
# train/7/n04373704_315.JPEG
# train/7/n04373704_2067.JPEG
# train/7/n04373704_4449.JPEG
# train/7/n04373704_2708.JPEG
# train/7/n04373704_2358.JPEG
# train/7/n04373704_2134.JPEG
# train/7/n04373704_7.JPEG
# train/7/n04373704_246.JPEG
# train/7/n04373704_1718.JPEG
# train/7/n04373704_2837.JPEG
# train/7/n04373704_1348.JPEG
# train/7/n04373704_2972.JPEG
# train/7/n04373704_2071.JPEG
# train/7/n04373704_2421.JPEG
# train/7/n04373704_1870.JPEG
# train/7/n04373704_4721.JPEG
# train/7/n04373704_1523.JPEG
# train/7/n04373704_1036.JPEG
# train/7/n04373704_5425.JPEG
# train/7/n04373704_641.JPEG
# train/7/n04373704_2925.JPEG
# train/7/n04373704_426.JPEG
# train/7/n04373704_4680.JPEG
# train/7/n04373704_3000.JPEG
# train/7/n04373704_2168.JPEG
# train/7/n04373704_2492.JPEG
# train/7/n04373704_4950.JPEG
# train/7/n04373704_1251.JPEG
# train/7/n04373704_1085.JPEG
# train/7/n04373704_888.JPEG
# train/7/n04373704_922.JPEG
# train/7/n04373704_1986.JPEG
# train/7/n04373704_2703.JPEG
# train/7/n04373704_5479.JPEG
# train/7/n04373704_1590.JPEG
# train/7/n04373704_2095.JPEG
# train/7/n04373704_4511.JPEG
# train/7/n04373704_1093.JPEG
# train/7/n04373704_488.JPEG
# train/7/n04373704_3738.JPEG
# train/7/n04373704_5253.JPEG
# train/7/n04373704_4911.JPEG
# train/7/n04373704_1210.JPEG
# train/7/n04373704_963.JPEG
# train/7/n04373704_1882.JPEG
# train/7/n04373704_5438.JPEG
# train/7/n04373704_3915.JPEG
# train/7/n04373704_1928.JPEG
# train/7/n04373704_1181.JPEG
# train/7/n04373704_4229.JPEG
# train/7/n04373704_1247.JPEG
# train/7/n04373704_2191.JPEG
# train/7/n04373704_2386.JPEG
# train/7/n04373704_5443.JPEG
# train/7/n04373704_1115.JPEG
# train/7/n04373704_2693.JPEG
# train/7/n04373704_2739.JPEG
# train/7/n04373704_1816.JPEG
# train/7/n04373704_2943.JPEG
# train/7/n04373704_762.JPEG
# train/7/n04373704_298.JPEG
# train/7/n04373704_2555.JPEG
# train/7/n04373704_277.JPEG
# train/7/n04373704_2105.JPEG
# train/7/n04373704_3344.JPEG
# train/7/n04373704_2806.JPEG
# train/7/n04373704_4205.JPEG
# train/7/n04373704_3939.JPEG
# train/7/n04373704_2781.JPEG
# train/7/n04373704_1841.JPEG
# train/7/n04373704_1512.JPEG
# train/7/n04373704_2017.JPEG
# train/7/n04373704_2914.JPEG
# train/7/n04373704_1791.JPEG
# train/7/n04373704_39.JPEG
# train/7/n04373704_220.JPEG
# train/7/n04373704_3885.JPEG
# train/7/n04373704_5117.JPEG
# train/7/n04373704_2778.JPEG
# train/7/n04373704_373.JPEG
# train/7/n04373704_723.JPEG
# train/7/n04373704_1338.JPEG
# train/7/n04373704_4301.JPEG
# train/7/n04373704_4881.JPEG
# train/7/n04373704_1380.JPEG
# train/7/n04373704_3647.JPEG
# train/7/n04373704_78.JPEG
# train/7/n04373704_1695.JPEG
# train/7/n04373704_4819.JPEG
# train/7/n04373704_216.JPEG
# train/7/n04373704_2164.JPEG
# train/7/n04373704_2867.JPEG
# train/7/n04373704_2888.JPEG
# train/7/n04373704_2922.JPEG
# train/7/n04373704_1877.JPEG
# train/7/n04373704_2758.JPEG
# train/7/n04373704_580.JPEG
# train/7/n04373704_5072.JPEG
# train/7/n04373704_4399.JPEG
# train/7/n04373704_4233.JPEG
# train/7/n04373704_3722.JPEG
# train/7/n04373704_2133.JPEG
# train/7/n04373704_2099.JPEG
# train/7/n04373704_2076.JPEG
# train/7/n04373704_2426.JPEG
# train/7/n04373704_4458.JPEG
# train/7/n04373704_1123.JPEG
# train/7/n04373704_1066.JPEG
# train/7/n04373704_1965.JPEG
# train/7/n04373704_2125.JPEG
# train/7/n04373704_607.JPEG
# train/7/n04373704_2430.JPEG
# train/7/n04373704_938.JPEG
# train/7/n04373704_1836.JPEG
# train/7/n04373704_200.JPEG
# train/7/n04373704_2467.JPEG
# train/7/n04373704_1498.JPEG
# train/7/n04373704_1027.JPEG
# train/7/n04373704_294.JPEG
# train/7/n04373704_1230.JPEG
# train/7/n04373704_2109.JPEG
# train/7/n04373704_2559.JPEG
# train/7/n04373704_1119.JPEG
# train/7/n04373704_3124.JPEG
# train/7/n04373704_914.JPEG
# train/7/n04373704_1637.JPEG
# train/7/n04373704_369.JPEG
# train/7/n04373704_693.JPEG
# train/7/n04373704_5224.JPEG
# train/7/n04373704_1322.JPEG
# train/7/n04373704_1288.JPEG
# train/7/n04373704_2627.JPEG
# train/7/n04373704_806.JPEG
# train/7/n04373704_410.JPEG
# train/7/n04373704_4073.JPEG
# train/7/n04373704_3759.JPEG
# train/7/n04373704_810.JPEG
# train/7/n04373704_2631.JPEG
# train/7/n04373704_2261.JPEG
# train/7/n04373704_2774.JPEG
# train/7/n04373704_955.JPEG
# train/7/n04373704_2959.JPEG
# train/7/n04373704_282.JPEG
# train/7/n04373704_4862.JPEG
# train/7/n04373704_4161.JPEG
# train/7/n04373704_74.JPEG
# train/7/n04373704_3427.JPEG
# train/7/n04373704_2373.JPEG
# train/7/n04373704_2237.JPEG
# train/7/n04373704_1948.JPEG
# train/7/n04373704_2958.JPEG
# train/7/n04373704_329.JPEG
# train/7/n04373704_1698.JPEG
# train/7/n04373704_2260.JPEG
# train/7/n04373704_1159.JPEG
# train/7/n04373704_1270.JPEG
# train/7/n04373704_4567.JPEG
# train/7/n04373704_2149.JPEG
# train/7/n04373704_2276.JPEG
# train/7/n04373704_2626.JPEG
# train/7/n04373704_3037.JPEG
# train/7/n04373704_2333.JPEG
# train/7/n04373704_692.JPEG
# train/7/n04373704_5225.JPEG
# train/7/n04373704_4571.JPEG
# train/7/n04373704_3060.JPEG
# train/7/n04373704_2364.JPEG
# train/7/n04373704_1661.JPEG
# train/7/n04373704_3349.JPEG
# train/7/n04373704_2108.JPEG
# train/7/n04373704_1860.JPEG
# train/7/n04373704_1163.JPEG
# train/7/n04373704_1134.JPEG
# train/7/n04373704_4336.JPEG
# train/7/n04373704_256.JPEG
# train/7/n04373704_2574.JPEG
# train/7/n04373704_2827.JPEG
# train/7/n04373704_1821.JPEG
# train/7/n04373704_186.JPEG
# train/7/n04373704_1964.JPEG
# train/7/n04373704_59.JPEG
# train/7/n04373704_2562.JPEG
# train/7/n04373704_2077.JPEG
# train/7/n04373704_755.JPEG
# train/7/n04373704_2427.JPEG
# train/7/n04373704_305.JPEG
# train/7/n04373704_4459.JPEG
# train/7/n04373704_3518.JPEG
# train/7/n04373704_1175.JPEG
# train/7/n04373704_1899.JPEG
# train/7/n04373704_647.JPEG
# train/7/n04373704_1319.JPEG
# train/7/n04373704_1749.JPEG
# train/7/n04373704_3261.JPEG
# train/7/n04373704_2923.JPEG
# train/7/n04373704_2057.JPEG
# train/7/n04373704_2407.JPEG
# train/7/n04373704_4496.JPEG
# train/7/n04373704_1047.JPEG
# train/7/n04373704_4615.JPEG
# train/7/n04373704_3979.JPEG
# train/7/n04373704_519.JPEG
# train/7/n04373704_2684.JPEG
# train/7/n04373704_1102.JPEG
# train/7/n04373704_2000.JPEG
# train/7/n04373704_5053.JPEG
# train/7/n04373704_1440.JPEG
# train/7/n04373704_1856.JPEG
# train/7/n04373704_2016.JPEG
# train/7/n04373704_4438.JPEG
# train/7/n04373704_2850.JPEG
# train/7/n04373704_4087.JPEG
# train/7/n04373704_3742.JPEG
# train/7/n04373704_5045.JPEG
# train/7/n04373704_2554.JPEG
# train/7/n04373704_1378.JPEG
# train/7/n04373704_1728.JPEG
# train/7/n04373704_5012.JPEG
# train/7/n04373704_1952.JPEG
# train/7/n04373704_1401.JPEG
# train/7/n04373704_1051.JPEG
# train/7/n04373704_4316.JPEG
# train/7/n04373704_2738.JPEG
# train/7/n04373704_4802.JPEG
# train/7/n04373704_2485.JPEG
# train/7/n04373704_14.JPEG
# train/7/n04373704_348.JPEG
# train/7/n04373704_5205.JPEG
# train/7/n04373704_3152.JPEG
# train/7/n04373704_4697.JPEG
# train/7/n04373704_1495.JPEG
# train/7/n04373704_3851.JPEG
# train/7/n04373704_1883.JPEG
# train/7/n04373704_3914.JPEG
# train/7/n04373704_827.JPEG
# train/7/n04373704_2128.JPEG
# train/7/n04373704_5317.JPEG
# train/7/n04373704_2082.JPEG
# train/7/n04373704_2597.JPEG
# train/7/n04373704_2714.JPEG
# train/7/n04373704_935.JPEG
# train/7/n04373704_1092.JPEG
# train/7/n04373704_3040.JPEG
# train/7/n04373704_2651.JPEG
# train/7/n04373704_489.JPEG
# train/7/n04373704_2997.JPEG
# train/7/n04373704_1712.JPEG
# train/7/n04373704_1207.JPEG
# train/7/n04373704_759.JPEG
# train/7/n04373704_2581.JPEG
# train/7/n04373704_923.JPEG
# train/7/n04373704_1315.JPEG
# train/7/n04373704_4117.JPEG
# train/7/n04373704_2493.JPEG
# train/7/n04373704_2539.JPEG
# train/7/n04373704_1250.JPEG
# train/7/n04373704_2755.JPEG
# train/7/n04373704_1483.JPEG
# train/7/n04373704_1179.JPEG
# train/7/n04373704_974.JPEG
# train/7/n04373704_831.JPEG
# train/7/n04373704_132.JPEG
# train/7/n04373704_1895.JPEG
# train/7/n04373704_2111.JPEG
# train/7/n04373704_3350.JPEG
# train/7/n04373704_1697.JPEG
# train/7/n04373704_1678.JPEG
# train/7/n04373704_1228.JPEG
# train/7/n04373704_4303.JPEG
# train/7/n04373704_1101.JPEG
# train/7/n04373704_1551.JPEG
# train/7/n04373704_4138.JPEG
# train/7/n04373704_2845.JPEG
# train/7/n04373704_2516.JPEG
# train/7/n04373704_1785.JPEG
# train/7/n04373704_1855.JPEG
# train/7/n04373704_2280.JPEG
# train/7/n04373704_1910.JPEG
# train/7/n04373704_4987.JPEG
# train/7/n04373704_388.JPEG
# train/7/n04373704_222.JPEG
# train/7/n04373704_1286.JPEG
# train/7/n04373704_1639.JPEG
# train/7/n04373704_1269.JPEG
# train/7/n04373704_2015.JPEG
# train/7/n04373704_3487.JPEG
# train/7/n04373704_2629.JPEG
# train/7/n04373704_808.JPEG
# train/7/n04373704_2804.JPEG
# train/7/n04373704_625.JPEG
# train/7/n04373704_2412.JPEG
# train/7/n04373704_2941.JPEG
# train/7/n04373704_1402.JPEG
# train/7/n04373704_1052.JPEG
# train/7/n04373704_2384.JPEG
# train/7/n04373704_4381.JPEG
# train/7/n04373704_3014.JPEG
# train/7/n04373704_1880.JPEG
# train/7/n04373704_577.JPEG
# train/7/n04373704_2310.JPEG
# train/7/n04373704_598.JPEG
# train/7/n04373704_961.JPEG
# train/7/n04373704_1496.JPEG
# train/7/n04373704_4440.JPEG
# train/7/n04373704_4913.JPEG
# train/7/n04373704_259.JPEG
# train/7/n04373704_40.JPEG
# train/7/n04373704_520.JPEG
# train/7/n04373704_2202.JPEG
# train/7/n04373704_1091.JPEG
# train/7/n04373704_465.JPEG
# train/7/n04373704_2428.JPEG
# train/7/n04373704_2078.JPEG
# train/7/n04373704_4143.JPEG
# train/7/n04373704_1341.JPEG
# train/7/n04373704_4513.JPEG
# train/7/n04373704_3055.JPEG
# train/7/n04373704_1068.JPEG
# train/7/n04373704_473.JPEG
# train/7/n04373704_2701.JPEG
# train/7/n04373704_920.JPEG
# train/7/n04373704_1603.JPEG
# train/7/n04373704_1253.JPEG
# train/7/n04373704_2869.JPEG
# train/7/n04373704_131.JPEG
# train/7/n04373704_2243.JPEG
# train/7/n04373704_3002.JPEG
# train/7/n04373704_998.JPEG
# train/7/n04373704_4682.JPEG
# train/7/n04373704_4728.JPEG
# train/7/n04373704_424.JPEG
# train/7/n04373704_453.JPEG
# train/7/n04373704_900.JPEG
# train/7/n04373704_1048.JPEG
# train/7/n04373704_3075.JPEG
# train/7/n04373704_845.JPEG
# train/7/n04373704_2234.JPEG
# train/7/n04373704_1731.JPEG
# train/7/n04373704_4860.JPEG
# train/7/n04373704_99.JPEG
# train/7/n04373704_1224.JPEG
# train/7/n04373704_3167.JPEG
# train/7/n04373704_2776.JPEG
# train/7/n04373704_2326.JPEG
# train/7/n04373704_111.JPEG
# train/7/n04373704_2263.JPEG
# train/7/n04373704_1336.JPEG
# train/7/n04373704_2330.JPEG
# train/7/n04373704_2760.JPEG
# train/7/n04373704_804.JPEG
# train/7/n04373704_3034.JPEG
# train/7/n04373704_557.JPEG
# train/7/n04373704_2275.JPEG
# train/7/n04373704_3608.JPEG
# train/7/n04373704_3126.JPEG
# train/7/n04373704_2367.JPEG
# train/7/n04373704_500.JPEG
# train/7/n04373704_2222.JPEG
# train/7/n04373704_783.JPEG
# train/7/n04373704_2808.JPEG
# train/7/n04373704_4525.JPEG
# train/7/n04373704_1398.JPEG
# train/7/n04373704_4460.JPEG
# train/7/n04373704_1662.JPEG
# train/7/n04373704_1025.JPEG
# train/7/n04373704_4677.JPEG
# train/7/n04373704_4362.JPEG
# train/7/n04373704_1530.JPEG
# train/7/n04373704_717.JPEG
# train/7/n04373704_1422.JPEG
# train/7/n04373704_1072.JPEG
# train/7/n04373704_486.JPEG
# train/7/n04373704_5174.JPEG
# train/7/n04373704_2598.JPEG
# train/7/n04373704_3389.JPEG
# train/7/n04373704_2824.JPEG
# train/7/n04373704_2577.JPEG
# train/7/n04373704_605.JPEG
# train/7/n04373704_2648.JPEG
# train/7/n04373704_2218.JPEG
# train/7/n04373704_1822.JPEG
# train/7/n04373704_1988.JPEG
# train/7/n04373704_3665.JPEG
# train/7/n04373704_2074.JPEG
# train/7/n04373704_306.JPEG
# train/7/n04373704_2131.JPEG
# train/7/n04373704_1199.JPEG
# train/7/n04373704_1463.JPEG
# train/7/n04373704_428.JPEG
# train/7/n04373704_5135.JPEG
# train/7/n04373704_1526.JPEG
# train/7/n04373704_2920.JPEG
# train/7/n04373704_2188.JPEG
# train/7/n04373704_700.JPEG
# train/7/n04373704_2864.JPEG
# train/7/n04373704_2537.JPEG
# train/7/n04373704_5071.JPEG
# train/7/n04373704_1874.JPEG
# train/7/n04373704_1177.JPEG
# train/7/n04373704_4375.JPEG
# train/7/n04373704_2075.JPEG
# train/7/n04373704_2425.JPEG
# train/7/n04373704_242.JPEG
# train/7/n04373704_2833.JPEG
# train/7/n04373704_3371.JPEG
# train/7/n04373704_491.JPEG
# train/7/n04373704_4267.JPEG
# train/7/n04373704_1823.JPEG
# train/7/n04373704_2433.JPEG
# train/7/n04373704_311.JPEG
# train/7/n04373704_2960.JPEG
# train/7/n04373704_2126.JPEG
# train/7/n04373704_604.JPEG
# train/7/n04373704_192.JPEG
# train/7/n04373704_1835.JPEG
# train/7/n04373704_3808.JPEG
# train/7/n04373704_4949.JPEG
# train/7/n04373704_2464.JPEG
# train/7/n04373704_2171.JPEG
# train/7/n04373704_2521.JPEG
# train/7/n04373704_4226.JPEG
# train/7/n04373704_4363.JPEG
# train/7/n04373704_4699.JPEG
# train/7/n04373704_1161.JPEG
# train/7/n04373704_1531.JPEG
# train/7/n04373704_595.JPEG
# train/7/n04373704_5335.JPEG
# train/7/n04373704_782.JPEG
# train/7/n04373704_61.JPEG
# train/7/n04373704_1399.JPEG
# train/7/n04373704_2366.JPEG
# train/7/n04373704_2389.JPEG
# train/7/n04373704_501.JPEG
# train/7/n04373704_852.JPEG
# train/7/n04373704_1321.JPEG
# train/7/n04373704_1771.JPEG
# train/7/n04373704_2018.JPEG
# train/7/n04373704_4436.JPEG
# train/7/n04373704_1008.JPEG
# train/7/n04373704_669.JPEG
# train/7/n04373704_393.JPEG
# train/7/n04373704_20.JPEG
# train/7/n04373704_1337.JPEG
# train/7/n04373704_4135.JPEG
# train/7/n04373704_4359.JPEG
# train/7/n04373704_956.JPEG
# train/7/n04373704_2777.JPEG
# train/7/n04373704_110.JPEG
# train/7/n04373704_2262.JPEG
# train/7/n04373704_4861.JPEG
# train/7/n04373704_4924.JPEG
# train/7/n04373704_281.JPEG
# train/7/n04373704_1225.JPEG
# train/7/n04373704_1675.JPEG
# train/7/n04373704_3131.JPEG
# train/7/n04373704_147.JPEG
# train/7/n04373704_2612.JPEG
# train/7/n04373704_1194.JPEG
# train/7/n04373704_999.JPEG
# train/7/n04373704_976.JPEG
# train/7/n04373704_4729.JPEG
# train/7/n04373704_1878.JPEG
# train/7/n04373704_2887.JPEG
# train/7/n04373704_1439.JPEG
# train/7/n04373704_1593.JPEG
# train/7/n04373704_3812.JPEG
# train/7/n04373704_921.JPEG
# train/7/n04373704_2079.JPEG
# train/7/n04373704_3668.JPEG
# train/7/n04373704_2995.JPEG
# train/7/n04373704_1340.JPEG
# train/7/n04373704_57.JPEG
# train/7/n04373704_2653.JPEG
# train/7/n04373704_872.JPEG
# train/7/n04373704_4338.JPEG
# train/7/n04373704_4441.JPEG
# train/7/n04373704_2829.JPEG
# train/7/n04373704_1182.JPEG
# train/7/n04373704_825.JPEG
# train/7/n04373704_126.JPEG
# train/7/n04373704_2311.JPEG
# train/7/n04373704_2741.JPEG
# train/7/n04373704_4945.JPEG
# train/7/n04373704_3629.JPEG
# train/7/n04373704_4553.JPEG
# train/7/n04373704_4800.JPEG
# train/7/n04373704_448.JPEG
# train/7/n04373704_1546.JPEG
# train/7/n04373704_4251.JPEG
# train/7/n04373704_2385.JPEG
# train/7/n04373704_1680.JPEG
# train/7/n04373704_274.JPEG
# train/7/n04373704_331.JPEG
# train/7/n04373704_2043.JPEG
# train/7/n04373704_1842.JPEG
# train/7/n04373704_809.JPEG
# train/7/n04373704_1454.JPEG
# train/7/n04373704_2151.JPEG
# train/7/n04373704_409.JPEG
# train/7/n04373704_2281.JPEG
# train/7/n04373704_1507.JPEG
# train/7/n04373704_3185.JPEG
# train/7/n04373704_1442.JPEG
# train/7/n04373704_5051.JPEG
# train/7/n04373704_3886.JPEG
# train/7/n04373704_4139.JPEG
# train/7/n04373704_1291.JPEG
# train/7/n04373704_4569.JPEG
# train/7/n04373704_3756.JPEG
# train/7/n04373704_2517.JPEG
# train/7/n04373704_370.JPEG
# train/7/n04373704_2452.JPEG
# train/7/n04373704_3243.JPEG
# train/7/n04373704_1803.JPEG
# train/7/n04373704_1045.JPEG
# train/7/n04373704_1415.JPEG
# train/7/n04373704_632.JPEG
# train/7/n04373704_2110.JPEG
# train/7/n04373704_1696.JPEG
# train/7/n04373704_1383.JPEG
# train/7/n04373704_2405.JPEG
# train/7/n04373704_2377.JPEG
# train/7/n04373704_2727.JPEG
# train/7/n04373704_3073.JPEG
# train/7/n04373704_843.JPEG
# train/7/n04373704_269.JPEG
# train/7/n04373704_4866.JPEG
# train/7/n04373704_70.JPEG
# train/7/n04373704_1672.JPEG
# train/7/n04373704_2770.JPEG
# train/7/n04373704_2320.JPEG
# train/7/n04373704_402.JPEG
# train/7/n04373704_3161.JPEG
# train/7/n04373704_2265.JPEG
# train/7/n04373704_27.JPEG
# train/7/n04373704_2009.JPEG
# train/7/n04373704_1849.JPEG
# train/7/n04373704_551.JPEG
# train/7/n04373704_101.JPEG
# train/7/n04373704_802.JPEG
# train/7/n04373704_4574.JPEG
# train/7/n04373704_1263.JPEG
# train/7/n04373704_1633.JPEG
# train/7/n04373704_4962.JPEG
# train/7/n04373704_910.JPEG
# train/7/n04373704_855.JPEG
# train/7/n04373704_1408.JPEG
# train/7/n04373704_3435.JPEG
# train/7/n04373704_4489.JPEG
# train/7/n04373704_5277.JPEG
# train/7/n04373704_89.JPEG
# train/7/n04373704_4221.JPEG
# train/7/n04373704_984.JPEG
# train/7/n04373704_4671.JPEG
# train/7/n04373704_5430.JPEG
# train/7/n04373704_1865.JPEG
# train/7/n04373704_1166.JPEG
# train/7/n04373704_2033.JPEG
# train/7/n04373704_2875.JPEG
# train/7/n04373704_204.JPEG
# train/7/n04373704_2208.JPEG
# train/7/n04373704_480.JPEG
# train/7/n04373704_879.JPEG
# train/7/n04373704_4276.JPEG
# train/7/n04373704_4299.JPEG
# train/7/n04373704_1561.JPEG
# train/7/n04373704_1131.JPEG
# train/7/n04373704_195.JPEG
# train/7/n04373704_5172.JPEG
# train/7/n04373704_2434.JPEG
# train/7/n04373704_746.JPEG
# train/7/n04373704_603.JPEG
# train/7/n04373704_2121.JPEG
# train/7/n04373704_2822.JPEG
# train/7/n04373704_1598.JPEG
# train/7/n04373704_1824.JPEG
# train/7/n04373704_183.JPEG
# train/7/n04373704_1577.JPEG
# train/7/n04373704_2072.JPEG
# train/7/n04373704_750.JPEG
# train/7/n04373704_2422.JPEG
# train/7/n04373704_3663.JPEG
# train/7/n04373704_3233.JPEG
# train/7/n04373704_4519.JPEG
# train/7/n04373704_4.JPEG
# train/7/n04373704_2567.JPEG
# train/7/n04373704_4667.JPEG
# train/7/n04373704_3008.JPEG
# train/7/n04373704_1170.JPEG
# train/7/n04373704_1873.JPEG
# train/7/n04373704_2025.JPEG
# train/7/n04373704_212.JPEG
# train/7/n04373704_3321.JPEG
# train/7/n04373704_3771.JPEG
# train/7/n04373704_2814.JPEG
# train/7/n04373704_3356.JPEG
# train/7/n04373704_4493.JPEG
# train/7/n04373704_2547.JPEG
# train/7/n04373704_2402.JPEG
# train/7/n04373704_2951.JPEG
# train/7/n04373704_93.JPEG
# train/7/n04373704_398.JPEG
# train/7/n04373704_4094.JPEG
# train/7/n04373704_1296.JPEG
# train/7/n04373704_2005.JPEG
# train/7/n04373704_727.JPEG
# train/7/n04373704_1150.JPEG
# train/7/n04373704_2793.JPEG
# train/7/n04373704_3881.JPEG
# train/7/n04373704_1015.JPEG
# train/7/n04373704_4217.JPEG
# train/7/n04373704_2156.JPEG
# train/7/n04373704_4981.JPEG
# train/7/n04373704_361.JPEG
# train/7/n04373704_1795.JPEG
# train/7/n04373704_418.JPEG
# train/7/n04373704_1516.JPEG
# train/7/n04373704_5294.JPEG
# train/7/n04373704_2101.JPEG
# train/7/n04373704_336.JPEG
# train/7/n04373704_2414.JPEG
# train/7/n04373704_2044.JPEG
# train/7/n04373704_2697.JPEG
# train/7/n04373704_1957.JPEG
# train/7/n04373704_2678.JPEG
# train/7/n04373704_5447.JPEG
# train/7/n04373704_2382.JPEG
# train/7/n04373704_1054.JPEG
# train/7/n04373704_859.JPEG
# train/7/n04373704_2195.JPEG
# train/7/n04373704_571.JPEG
# train/7/n04373704_988.JPEG
# train/7/n04373704_1490.JPEG
# train/7/n04373704_434.JPEG
# train/7/n04373704_2316.JPEG
# train/7/n04373704_3854.JPEG
# train/7/n04373704_1869.JPEG
# train/7/n04373704_1644.JPEG
# train/7/n04373704_1214.JPEG
# train/7/n04373704_3415.JPEG
# train/7/n04373704_2341.JPEG
# train/7/n04373704_199.JPEG
# train/7/n04373704_930.JPEG
# train/7/n04373704_1097.JPEG
# train/7/n04373704_3395.JPEG
# train/7/n04373704_249.JPEG
# train/7/n04373704_619.JPEG
# train/7/n04373704_50.JPEG
# train/7/n04373704_2212.JPEG
# train/7/n04373704_160.JPEG
# train/7/n04373704_3053.JPEG
# train/7/n04373704_5168.JPEG
# train/7/n04373704_1828.JPEG
# train/7/n04373704_3815.JPEG
# train/7/n04373704_2029.JPEG
# train/7/n04373704_2479.JPEG
# train/7/n04373704_2183.JPEG
# train/7/n04373704_3004.JPEG
# train/7/n04373704_1193.JPEG
# train/7/n04373704_4391.JPEG
# train/7/n04373704_3454.JPEG
# train/7/n04373704_2615.JPEG
# train/7/n04373704_137.JPEG
# train/7/n04373704_2300.JPEG
# train/7/n04373704_1486.JPEG
# train/7/n04373704_835.JPEG
# train/7/n04373704_2614.JPEG
# train/7/n04373704_2244.JPEG
# train/7/n04373704_3793.JPEG
# train/7/n04373704_1741.JPEG
# train/7/n04373704_4113.JPEG
# train/7/n04373704_531.JPEG
# train/7/n04373704_5186.JPEG
# train/7/n04373704_862.JPEG
# train/7/n04373704_3052.JPEG
# train/7/n04373704_4328.JPEG
# train/7/n04373704_3117.JPEG
# train/7/n04373704_3814.JPEG
# train/7/n04373704_2090.JPEG
# train/7/n04373704_618.JPEG
# train/7/n04373704_1079.JPEG
# train/7/n04373704_3044.JPEG
# train/7/n04373704_177.JPEG
# train/7/n04373704_2205.JPEG
# train/7/n04373704_527.JPEG
# train/7/n04373704_1995.JPEG
# train/7/n04373704_1215.JPEG
# train/7/n04373704_1350.JPEG
# train/7/n04373704_3013.JPEG
# train/7/n04373704_823.JPEG
# train/7/n04373704_2317.JPEG
# train/7/n04373704_3855.JPEG
# train/7/n04373704_1242.JPEG
# train/7/n04373704_4806.JPEG
# train/7/n04373704_2878.JPEG
# train/7/n04373704_4555.JPEG
# train/7/n04373704_1956.JPEG
# train/7/n04373704_2679.JPEG
# train/7/n04373704_858.JPEG
# train/7/n04373704_3068.JPEG
# train/7/n04373704_2550.JPEG
# train/7/n04373704_1239.JPEG
# train/7/n04373704_1669.JPEG
# train/7/n04373704_2415.JPEG
# train/7/n04373704_337.JPEG
# train/7/n04373704_1844.JPEG
# train/7/n04373704_1147.JPEG
# train/7/n04373704_4715.JPEG
# train/7/n04373704_1002.JPEG
# train/7/n04373704_1452.JPEG
# train/7/n04373704_1901.JPEG
# train/7/n04373704_5041.JPEG
# train/7/n04373704_2784.JPEG
# train/7/n04373704_2157.JPEG
# train/7/n04373704_3603.JPEG
# train/7/n04373704_1151.JPEG
# train/7/n04373704_3479.JPEG
# train/7/n04373704_663.JPEG
# train/7/n04373704_3300.JPEG
# train/7/n04373704_1297.JPEG
# train/7/n04373704_2680.JPEG
# train/7/n04373704_1106.JPEG
# train/7/n04373704_1556.JPEG
# train/7/n04373704_4241.JPEG
# train/7/n04373704_1043.JPEG
# train/7/n04373704_2815.JPEG
# train/7/n04373704_1690.JPEG
# train/7/n04373704_2116.JPEG
# train/7/n04373704_771.JPEG
# train/7/n04373704_2024.JPEG
# train/7/n04373704_2531.JPEG
# train/7/n04373704_2248.JPEG
# train/7/n04373704_2618.JPEG
# train/7/n04373704_1937.JPEG
# train/7/n04373704_1034.JPEG
# train/7/n04373704_1521.JPEG
# train/7/n04373704_5132.JPEG
# train/7/n04373704_585.JPEG
# train/7/n04373704_1063.JPEG
# train/7/n04373704_478.JPEG
# train/7/n04373704_1219.JPEG
# train/7/n04373704_2989.JPEG
# train/7/n04373704_5036.JPEG
# train/7/n04373704_1976.JPEG
# train/7/n04373704_481.JPEG
# train/7/n04373704_4277.JPEG
# train/7/n04373704_1130.JPEG
# train/7/n04373704_2032.JPEG
# train/7/n04373704_2177.JPEG
# train/7/n04373704_205.JPEG
# train/7/n04373704_5431.JPEG
# train/7/n04373704_439.JPEG
# train/7/n04373704_1537.JPEG
# train/7/n04373704_1720.JPEG
# train/7/n04373704_5299.JPEG
# train/7/n04373704_2419.JPEG
# train/7/n04373704_88.JPEG
# train/7/n04373704_2730.JPEG
# train/7/n04373704_3988.JPEG
# train/7/n04373704_3121.JPEG
# train/7/n04373704_3571.JPEG
# train/7/n04373704_854.JPEG
# train/7/n04373704_1327.JPEG
# train/7/n04373704_13089.JPEG
# train/7/n04373704_4349.JPEG
# train/7/n04373704_3176.JPEG
# train/7/n04373704_415.JPEG
# train/7/n04373704_2767.JPEG
# train/7/n04373704_1331.JPEG
# train/7/n04373704_5237.JPEG
# train/7/n04373704_2458.JPEG
# train/7/n04373704_950.JPEG
# train/7/n04373704_116.JPEG
# train/7/n04373704_2634.JPEG
# train/7/n04373704_268.JPEG
# train/7/n04373704_71.JPEG
# train/7/n04373704_1223.JPEG
# train/7/n04373704_1389.JPEG
# train/7/n04373704_4471.JPEG
# train/7/n04373704_2376.JPEG
# train/7/n04373704_3834.JPEG
# train/7/n04373704_2233.JPEG
# train/7/n04373704_842.JPEG
# train/7/n04373704_3072.JPEG
# train/0/n01910747_1536.JPEG
# train/0/n01910747_1473.JPEG
# train/0/n01910747_8652.JPEG
# train/0/n01910747_8202.JPEG
# train/0/n01910747_3337.JPEG
# train/0/n01910747_16439.JPEG
# train/0/n01910747_17678.JPEG
# train/0/n01910747_3272.JPEG
# train/0/n01910747_9501.JPEG
# train/0/n01910747_13400.JPEG
# train/0/n01910747_1561.JPEG
# train/0/n01910747_16252.JPEG
# train/0/n01910747_12354.JPEG
# train/0/n01910747_13816.JPEG
# train/0/n01910747_16317.JPEG
# train/0/n01910747_7773.JPEG
# train/0/n01910747_10040.JPEG
# train/0/n01910747_14003.JPEG
# train/0/n01910747_13396.JPEG
# train/0/n01910747_11651.JPEG
# train/0/n01910747_13379.JPEG
# train/0/n01910747_9278.JPEG
# train/0/n01910747_7159.JPEG
# train/0/n01910747_15192.JPEG
# train/0/n01910747_7509.JPEG
# train/0/n01910747_16244.JPEG
# train/0/n01910747_8613.JPEG
# train/0/n01910747_16182.JPEG
# train/0/n01910747_10056.JPEG
# train/0/n01910747_7270.JPEG
# train/0/n01910747_10810.JPEG
# train/0/n01910747_3399.JPEG
# train/0/n01910747_9794.JPEG
# train/0/n01910747_1520.JPEG
# train/0/n01910747_3008.JPEG
# train/0/n01910747_4667.JPEG
# train/0/n01910747_15653.JPEG
# train/0/n01910747_10451.JPEG
# train/0/n01910747_11305.JPEG
# train/0/n01910747_1609.JPEG
# train/0/n01910747_6965.JPEG
# train/0/n01910747_15151.JPEG
# train/0/n01910747_10703.JPEG
# train/0/n01910747_16268.JPEG
# train/0/n01910747_9491.JPEG
# train/0/n01910747_10216.JPEG
# train/0/n01910747_9242.JPEG
# train/0/n01910747_16907.JPEG
# train/0/n01910747_9307.JPEG
# train/0/n01910747_9583.JPEG
# train/0/n01910747_3024.JPEG
# train/0/n01910747_8668.JPEG
# train/0/n01910747_7437.JPEG
# train/0/n01910747_7122.JPEG
# train/0/n01910747_7572.JPEG
# train/0/n01910747_10241.JPEG
# train/0/n01910747_16546.JPEG
# train/0/n01910747_1625.JPEG
# train/0/n01910747_9215.JPEG
# train/0/n01910747_16403.JPEG
# train/0/n01910747_5689.JPEG
# train/0/n01910747_17642.JPEG
# train/0/n01910747_10312.JPEG
# train/0/n01910747_11850.JPEG
# train/0/n01910747_17438.JPEG
# train/0/n01910747_8412.JPEG
# train/0/n01910747_8042.JPEG
# train/0/n01910747_10191.JPEG
# train/0/n01910747_9468.JPEG
# train/0/n01910747_10715.JPEG
# train/0/n01910747_7476.JPEG
# train/0/n01910747_11041.JPEG
# train/0/n01910747_9604.JPEG
# train/0/n01910747_14185.JPEG
# train/0/n01910747_17603.JPEG
# train/0/n01910747_3291.JPEG
# train/0/n01910747_9223.JPEG
# train/0/n01910747_9389.JPEG
# train/0/n01910747_4942.JPEG
# train/0/n01910747_10298.JPEG
# train/0/n01910747_11870.JPEG
# train/0/n01910747_15833.JPEG
# train/0/n01910747_9761.JPEG
# train/0/n01910747_2984.JPEG
# train/0/n01910747_8170.JPEG
# train/0/n01910747_16931.JPEG
# train/0/n01910747_11718.JPEG
# train/0/n01910747_13375.JPEG
# train/0/n01910747_10670.JPEG
# train/0/n01910747_15921.JPEG
# train/0/n01910747_11124.JPEG
# train/0/n01910747_8536.JPEG
# train/0/n01910747_17265.JPEG
# train/0/n01910747_6178.JPEG
# train/0/n01910747_13676.JPEG
# train/0/n01910747_13733.JPEG
# train/0/n01910747_7786.JPEG
# train/0/n01910747_11077.JPEG
# train/0/n01910747_7010.JPEG
# train/0/n01910747_3053.JPEG
# train/0/n01910747_6085.JPEG
# train/0/n01910747_6986.JPEG
# train/0/n01910747_12460.JPEG
# train/0/n01910747_16970.JPEG
# train/0/n01910747_17377.JPEG
# train/0/n01910747_10133.JPEG
# train/0/n01910747_15624.JPEG
# train/0/n01910747_17619.JPEG
# train/0/n01910747_6787.JPEG
# train/0/n01910747_7483.JPEG
# train/0/n01910747_12677.JPEG
# train/0/n01910747_9864.JPEG
# train/0/n01910747_9219.JPEG
# train/0/n01910747_6046.JPEG
# train/0/n01910747_16819.JPEG
# train/0/n01910747_4978.JPEG
# train/0/n01910747_15389.JPEG
# train/0/n01910747_3751.JPEG
# train/0/n01910747_6103.JPEG
# train/0/n01910747_9976.JPEG
# train/0/n01910747_3028.JPEG
# train/0/n01910747_13524.JPEG
# train/0/n01910747_13031.JPEG
# train/0/n01910747_8371.JPEG
# train/0/n01910747_17072.JPEG
# train/0/n01910747_6953.JPEG
# train/0/n01910747_11299.JPEG
# train/0/n01910747_11763.JPEG
# train/0/n01910747_11626.JPEG
# train/0/n01910747_16419.JPEG
# train/0/n01910747_10037.JPEG
# train/0/n01910747_15235.JPEG
# train/0/n01910747_5369.JPEG
# train/0/n01910747_5105.JPEG
# train/0/n01910747_4714.JPEG
# train/0/n01910747_13477.JPEG
# train/0/n01910747_15777.JPEG
# train/0/n01910747_6512.JPEG
# train/0/n01910747_17526.JPEG
# train/0/n01910747_12724.JPEG
# train/0/n01910747_15848.JPEG
# train/0/n01910747_9464.JPEG
# train/0/n01910747_3439.JPEG
# train/0/n01910747_1541.JPEG
# train/0/n01910747_4743.JPEG
# train/0/n01910747_5502.JPEG
# train/0/n01910747_12725.JPEG
# train/0/n01910747_16336.JPEG
# train/0/n01910747_9520.JPEG
# train/0/n01910747_16623.JPEG
# train/0/n01910747_5153.JPEG
# train/0/n01910747_11735.JPEG
# train/0/n01910747_8448.JPEG
# train/0/n01910747_7247.JPEG
# train/0/n01910747_14022.JPEG
# train/0/n01910747_1686.JPEG
# train/0/n01910747_8223.JPEG
# train/0/n01910747_17435.JPEG
# train/0/n01910747_1517.JPEG
# train/0/n01910747_15371.JPEG
# train/0/n01910747_15234.JPEG
# train/0/n01910747_17659.JPEG
# train/0/n01910747_5057.JPEG
# train/0/n01910747_15808.JPEG
# train/0/n01910747_16727.JPEG
# train/0/n01910747_13525.JPEG
# train/0/n01910747_13175.JPEG
# train/0/n01910747_1444.JPEG
# train/0/n01910747_5112.JPEG
# train/0/n01910747_1628.JPEG
# train/0/.DS_Store
# train/0/n01910747_12733.JPEG
# train/0/n01910747_17474.JPEG
# train/0/n01910747_3091.JPEG
# train/0/n01910747_7601.JPEG
# train/0/n01910747_10132.JPEG
# train/0/n01910747_11723.JPEG
# train/0/n01910747_5283.JPEG
# train/0/n01910747_7553.JPEG
# train/0/n01910747_10260.JPEG
# train/0/n01910747_14673.JPEG
# train/0/n01910747_10325.JPEG
# train/0/n01910747_10237.JPEG
# train/0/n01910747_9849.JPEG
# train/0/n01910747_15465.JPEG
# train/0/n01910747_10688.JPEG
# train/0/n01910747_3402.JPEG
# train/0/n01910747_6529.JPEG
# train/0/n01910747_3681.JPEG
# train/0/n01910747_3394.JPEG
# train/0/n01910747_12820.JPEG
# train/0/n01910747_6895.JPEG
# train/0/n01910747_7841.JPEG
# train/0/n01910747_3044.JPEG
# train/0/n01910747_2985.JPEG
# train/0/n01910747_9330.JPEG
# train/0/n01910747_8034.JPEG
# train/0/n01910747_16526.JPEG
# train/0/n01910747_7050.JPEG
# train/0/n01910747_6138.JPEG
# train/0/n01910747_16121.JPEG
# train/0/n01910747_3658.JPEG
# train/0/n01910747_13354.JPEG
# train/0/n01910747_10597.JPEG
# train/0/n01910747_6636.JPEG
# train/0/n01910747_13568.JPEG
# train/0/n01910747_12729.JPEG
# train/0/n01910747_7498.JPEG
# train/0/n01910747_6773.JPEG
# train/0/n01910747_15900.JPEG
# train/0/n01910747_11410.JPEG
# train/0/n01910747_8413.JPEG
# train/0/n01910747_16947.JPEG
# train/0/n01910747_10893.JPEG
# train/0/n01910747_3930.JPEG
# train/0/n01910747_3033.JPEG
# train/0/n01910747_13180.JPEG
# train/0/n01910747_7836.JPEG
# train/0/n01910747_16117.JPEG
# train/0/n01910747_13250.JPEG
# train/0/n01910747_17643.JPEG
# train/0/n01910747_3863.JPEG
# train/0/n01910747_11685.JPEG
# train/0/n01910747_8901.JPEG
# train/0/n01910747_4021.JPEG
# train/0/n01910747_7461.JPEG
# train/0/n01910747_3422.JPEG
# train/0/n01910747_3834.JPEG
# train/0/n01910747_17028.JPEG
# train/0/n01910747_15652.JPEG
# train/0/n01910747_7699.JPEG
# train/0/n01910747_11611.JPEG
# train/0/n01910747_1521.JPEG
# train/0/n01910747_10329.JPEG
# train/0/n01910747_9404.JPEG
# train/0/n01910747_16357.JPEG
# train/0/n01910747_11168.JPEG
# train/0/n01910747_6175.JPEG
# train/0/n01910747_10057.JPEG
# train/0/n01910747_15255.JPEG
# train/0/n01910747_11979.JPEG
# train/0/n01910747_8307.JPEG
# train/0/n01910747_13102.JPEG
# train/0/n01910747_8612.JPEG
# train/0/n01910747_8487.JPEG
# train/0/n01910747_3361.JPEG
# train/0/n01910747_11345.JPEG
# train/0/n01910747_6476.JPEG
# train/0/n01910747_17291.JPEG
# train/0/n01910747_14844.JPEG
# train/0/n01910747_13401.JPEG
# train/0/n01910747_1560.JPEG
# train/0/n01910747_9150.JPEG
# train/0/n01910747_15185.JPEG
# train/0/n01910747_10387.JPEG
# train/0/n01910747_17507.JPEG
# train/0/n01910747_6134.JPEG
# train/0/n01910747_8983.JPEG
# train/0/n01910747_15351.JPEG
# train/0/n01910747_12617.JPEG
# train/0/n01910747_17045.JPEG
# train/0/n01910747_12247.JPEG
# train/0/n01910747_9412.JPEG
# train/0/n01910747_8203.JPEG
# train/0/n01910747_16433.JPEG
# train/0/n01910747_16825.JPEG
# train/0/n01910747_17737.JPEG
# train/0/n01910747_6979.JPEG
# train/0/n01910747_16576.JPEG
# train/0/n01910747_15970.JPEG
# train/0/n01910747_7811.JPEG
# train/0/n01910747_11525.JPEG
# train/0/n01910747_5969.JPEG
# train/0/n01910747_6646.JPEG
# train/0/n01910747_11876.JPEG
# train/0/n01910747_3690.JPEG
# train/0/n01910747_10949.JPEG
# train/0/n01910747_16034.JPEG
# train/0/n01910747_9337.JPEG
# train/0/n01910747_1642.JPEG
# train/0/n01910747_6884.JPEG
# train/0/n01910747_9858.JPEG
# train/0/n01910747_7145.JPEG
# train/0/n01910747_3043.JPEG
# train/0/n01910747_16022.JPEG
# train/0/n01910747_16188.JPEG
# train/0/n01910747_2994.JPEG
# train/0/n01910747_14859.JPEG
# train/0/n01910747_10119.JPEG
# train/0/n01910747_11358.JPEG
# train/0/n01910747_15874.JPEG
# train/0/n01910747_1438.JPEG
# train/0/n01910747_5355.JPEG
# train/0/n01910747_16425.JPEG
# train/0/n01910747_12489.JPEG
# train/0/n01910747_12523.JPEG
# train/0/n01910747_9819.JPEG
# train/0/n01910747_15435.JPEG
# train/0/n01910747_16848.JPEG
# train/0/n01910747_7313.JPEG
# train/0/n01910747_14033.JPEG
# train/0/n01910747_13826.JPEG
# train/0/n01910747_17166.JPEG
# train/0/n01910747_8265.JPEG
# train/0/n01910747_1551.JPEG
# train/0/n01910747_16632.JPEG
# train/0/n01910747_7651.JPEG
# train/0/n01910747_11773.JPEG
# train/0/n01910747_16370.JPEG
# train/0/n01910747_9566.JPEG
# train/0/n01910747_6739.JPEG
# train/0/n01910747_4704.JPEG
# train/0/n01910747_8418.JPEG
# train/0/n01910747_12775.JPEG
# train/0/n01910747_3038.JPEG
# train/0/n01910747_7997.JPEG
# train/0/n01910747_4342.JPEG
# train/0/n01910747_13922.JPEG
# train/0/n01910747_7094.JPEG
# train/0/n01910747_9989.JPEG
# train/0/n01910747_1681.JPEG
# train/0/n01910747_13563.JPEG
# train/0/n01910747_6282.JPEG
# train/0/n01910747_9803.JPEG
# train/0/n01910747_17042.JPEG
# train/0/n01910747_17557.JPEG
# train/0/n01910747_13144.JPEG
# train/0/n01910747_15993.JPEG
# train/0/n01910747_4227.JPEG
# train/0/n01910747_3018.JPEG
# train/0/n01910747_7722.JPEG
# train/0/n01910747_14951.JPEG
# train/0/n01910747_9679.JPEG
# train/0/n01910747_15028.JPEG
# train/0/n01910747_9854.JPEG
# train/0/n01910747_17853.JPEG
# train/0/n01910747_17150.JPEG
# train/0/n01910747_6534.JPEG
# train/0/n01910747_16468.JPEG
# train/0/n01910747_4159.JPEG
# train/0/n01910747_16891.JPEG
# train/0/n01910747_6867.JPEG
# train/0/n01910747_10553.JPEG
# train/0/n01910747_8750.JPEG
# train/0/n01910747_9842.JPEG
# train/0/n01910747_15194.JPEG
# train/0/n01910747_5162.JPEG
# train/0/n01910747_17003.JPEG
# train/0/n01910747_15481.JPEG
# train/0/n01910747_15878.JPEG
# train/0/n01910747_7763.JPEG
# train/0/n01910747_10050.JPEG
# train/0/n01910747_3720.JPEG
# train/0/n01910747_2977.JPEG
# train/0/n01910747_1658.JPEG
# train/0/n01910747_3848.JPEG
# train/0/n01910747_12606.JPEG
# train/0/n01910747_9815.JPEG
# train/0/n01910747_13447.JPEG
# train/0/n01910747_16215.JPEG
# train/0/n01910747_10284.JPEG
# train/0/n01910747_12939.JPEG
# train/0/n01910747_3327.JPEG
# train/0/n01910747_5709.JPEG
# train/0/n01910747_14802.JPEG
# train/0/n01910747_7036.JPEG
# train/0/n01910747_17756.JPEG
# train/0/n01910747_8455.JPEG
# train/0/n01910747_4476.JPEG
# train/0/n01910747_9244.JPEG
# train/0/n01910747_4026.JPEG
# train/0/n01910747_11513.JPEG
# train/0/n01910747_4708.JPEG
# train/0/n01910747_10247.JPEG
# train/0/n01910747_3.JPEG
# train/0/n01910747_9213.JPEG
# train/0/n01910747_12016.JPEG
# train/0/n01910747_10181.JPEG
# train/0/n01910747_15679.JPEG
# train/0/n01910747_9706.JPEG
# train/0/n01910747_12915.JPEG
# train/0/n01910747_3034.JPEG
# train/0/n01910747_9439.JPEG
# train/0/n01910747_8382.JPEG
# train/0/n01910747_7077.JPEG
# train/0/n01910747_6723.JPEG
# train/0/n01910747_8414.JPEG
# train/0/n01910747_16556.JPEG
# train/0/n01910747_10713.JPEG
# train/0/n01910747_8785.JPEG
# train/0/n01910747_6631.JPEG
# train/0/n01910747_9194.JPEG
# train/0/n01910747_16782.JPEG
# train/0/n01910747_9481.JPEG
# train/0/n01910747_12811.JPEG
# train/0/n01910747_1663.JPEG
# train/0/n01910747_15286.JPEG
# train/0/n01910747_15269.JPEG
# train/0/n01910747_12685.JPEG
# train/0/n01910747_6630.JPEG
# train/0/n01910747_3062.JPEG
# train/0/n01910747_7164.JPEG
# train/0/n01910747_10207.JPEG
# train/0/n01910747_4965.JPEG
# train/0/n01910747_13305.JPEG
# train/0/n01910747_12847.JPEG
# train/0/n01910747_9341.JPEG
# train/0/n01910747_13610.JPEG
# train/0/n01910747_15117.JPEG
# train/0/n01910747_15951.JPEG
# train/0/n01910747_13743.JPEG
# train/0/n01910747_16541.JPEG
# train/0/n01910747_16812.JPEG
# train/0/n01910747_15551.JPEG
# train/0/n01910747_14710.JPEG
# train/0/n01910747_11007.JPEG
# train/0/n01910747_15947.JPEG
# train/0/n01910747_13190.JPEG
# train/0/n01910747_14481.JPEG
# train/0/n01910747_11379.JPEG
# train/0/n01910747_1675.JPEG
# train/0/n01910747_16516.JPEG
# train/0/n01910747_16453.JPEG
# train/0/n01910747_17242.JPEG
# train/0/n01910747_7467.JPEG
# train/0/n01910747_7522.JPEG
# train/0/n01910747_13780.JPEG
# train/0/n01910747_3326.JPEG
# train/0/n01910747_17393.JPEG
# train/0/n01910747_15204.JPEG
# train/0/n01910747_6827.JPEG
# train/0/n01910747_7220.JPEG
# train/0/n01910747_3799.JPEG
# train/0/n01910747_11181.JPEG
# train/0/n01910747_9547.JPEG
# train/0/n01910747_15316.JPEG
# train/0/n01910747_13041.JPEG
# train/0/n01910747_10397.JPEG
# train/0/n01910747_17517.JPEG
# train/0/n01910747_12345.JPEG
# train/0/n01910747_11139.JPEG
# train/0/n01910747_8878.JPEG
# train/0/n01910747_16469.JPEG
# train/0/n01910747_10801.JPEG
# train/0/n01910747_11713.JPEG
# train/0/n01910747_16255.JPEG
# train/0/n01910747_1566.JPEG
# train/0/n01910747_11085.JPEG
# train/0/n01910747_5067.JPEG
# train/0/n01910747_17106.JPEG
# train/0/n01910747_3019.JPEG
# train/0/n01910747_6796.JPEG
# train/0/n01910747_17171.JPEG
# train/0/n01910747_13427.JPEG
# train/0/n01910747_1546.JPEG
# train/0/n01910747_11363.JPEG
# train/0/n01910747_6000.JPEG
# train/0/n01910747_16449.JPEG
# train/0/n01910747_7754.JPEG
# train/0/n01910747_9967.JPEG
# train/0/n01910747_15818.JPEG
# train/0/n01910747_9658.JPEG
# train/0/n01910747_15727.JPEG
# train/0/n01910747_15232.JPEG
# train/0/n01910747_14073.JPEG
# train/0/n01910747_1442.JPEG
# train/0/n01910747_7083.JPEG
# train/0/n01910747_7200.JPEG
# train/0/n01910747_10163.JPEG
# train/0/n01910747_14120.JPEG
# train/0/n01910747_4586.JPEG
# train/0/n01910747_13827.JPEG
# train/0/n01910747_7938.JPEG
# train/0/n01910747_16776.JPEG
# train/0/n01910747_6295.JPEG
# train/0/n01910747_4752.JPEG
# train/0/n01910747_4302.JPEG
# train/0/n01910747_13962.JPEG
# train/0/n01910747_13348.JPEG
# train/0/n01910747_8458.JPEG
# train/0/n01910747_11660.JPEG
# train/0/n01910747_14032.JPEG
# train/0/n01910747_11027.JPEG
# train/0/n01910747_15967.JPEG
# train/0/n01910747_16648.JPEG
# train/0/n01910747_15064.JPEG
# train/0/n01910747_3900.JPEG
# train/0/n01910747_16977.JPEG
# train/0/n01910747_8566.JPEG
# train/0/n01910747_9727.JPEG
# train/0/n01910747_10909.JPEG
# train/0/n01910747_9662.JPEG
# train/0/n01910747_7386.JPEG
# train/0/n01910747_12488.JPEG
# train/0/n01910747_15033.JPEG
# train/0/n01910747_11420.JPEG
# train/0/n01910747_7914.JPEG
# train/0/n01910747_1655.JPEG
# train/0/n01910747_8927.JPEG
# train/0/n01910747_7847.JPEG
# train/0/n01910747_11820.JPEG
# train/0/n01910747_11123.JPEG
# train/0/n01910747_1585.JPEG
# train/0/n01910747_7328.JPEG
# train/0/n01910747_16465.JPEG
# train/0/n01910747_2983.JPEG
# train/0/n01910747_4504.JPEG
# train/0/n01910747_6539.JPEG
# train/0/n01910747_6186.JPEG
# train/0/n01910747_17331.JPEG
# train/0/n01910747_7543.JPEG
# train/0/n01910747_10270.JPEG
# train/0/n01910747_7685.JPEG
# train/0/n01910747_8435.JPEG
# train/0/n01910747_9525.JPEG
# train/0/n01910747_4747.JPEG
# train/0/n01910747_7868.JPEG
# train/0/n01910747_8334.JPEG
# train/0/n01910747_9876.JPEG
# train/0/n01910747_12665.JPEG
# train/0/n01910747_9899.JPEG
# train/0/n01910747_17871.JPEG
# train/0/n01910747_16763.JPEG
# train/0/n01910747_14027.JPEG
# train/0/n01910747_3344.JPEG
# train/0/n01910747_13473.JPEG
# train/0/n01910747_16364.JPEG
# train/0/n01910747_4086.JPEG
# train/0/n01910747_10033.JPEG
# train/0/n01910747_17719.JPEG
# train/0/n01910747_7983.JPEG
# train/0/n01910747_12274.JPEG
# train/0/n01910747_9972.JPEG
# train/0/n01910747_8660.JPEG
# train/0/n01910747_16958.JPEG
# train/0/n01910747_10025.JPEG
# train/0/n01910747_10160.JPEG
# train/0/n01910747_5005.JPEG
# train/0/n01910747_3978.JPEG
# train/0/n01910747_6150.JPEG
# train/0/n01910747_10422.JPEG
# train/0/n01910747_7805.JPEG
# train/0/n01910747_7385.JPEG
# train/0/n01910747_9374.JPEG
# train/0/n01910747_3779.JPEG
# train/0/n01910747_11835.JPEG
# train/0/n01910747_1590.JPEG
# train/0/n01910747_6310.JPEG
# train/0/n01910747_11589.JPEG
# train/0/n01910747_7852.JPEG
# train/0/n01910747_1656.JPEG
# train/0/n01910747_10818.JPEG
# train/0/n01910747_16866.JPEG
# train/0/n01910747_12599.JPEG
# train/0/n01910747_15533.JPEG
# train/0/n01910747_5879.JPEG
# train/0/n01910747_8932.JPEG
# train/0/n01910747_3368.JPEG
# train/0/n01910747_16036.JPEG
# train/0/n01910747_13234.JPEG
# train/0/n01910747_12425.JPEG
# train/0/n01910747_15837.JPEG
# train/0/n01910747_1494.JPEG
# train/0/n01910747_15071.JPEG
# train/0/n01910747_4415.JPEG
# train/0/n01910747_6582.JPEG
# train/0/n01910747_8573.JPEG
# train/0/n01910747_12472.JPEG
# train/0/n01910747_17670.JPEG
# train/0/n01910747_16962.JPEG
# train/0/n01910747_17220.JPEG
# train/0/n01910747_8857.JPEG
# train/0/n01910747_11229.JPEG
# train/0/n01910747_8011.JPEG
# train/0/n01910747_8441.JPEG
# train/0/n01910747_12669.JPEG
# train/0/n01910747_9483.JPEG
# train/0/n01910747_3061.JPEG
# train/0/n01910747_15143.JPEG
# train/0/n01910747_13243.JPEG
# train/0/n01910747_17715.JPEG
# train/0/n01910747_4966.JPEG
# train/0/n01910747_14990.JPEG
# train/0/n01910747_13185.JPEG
# train/0/n01910747_14210.JPEG
# train/0/n01910747_4209.JPEG
# train/0/n01910747_6234.JPEG
# train/0/n01910747_15381.JPEG
# train/0/n01910747_14986.JPEG
# train/0/n01910747_12501.JPEG
# train/0/n01910747_17703.JPEG
# train/0/n01910747_12628.JPEG
# train/0/n01910747_17580.JPEG
# train/0/n01910747_16391.JPEG
# train/0/n01910747_9753.JPEG
# train/0/n01910747_4474.JPEG
# train/0/n01910747_10992.JPEG
# train/0/n01910747_16846.JPEG
# train/0/n01910747_4927.JPEG
# train/0/n01910747_3098.JPEG
# train/0/n01910747_16796.JPEG
# train/0/n01910747_17884.JPEG
# train/0/n01910747_3831.JPEG
# train/0/n01910747_9180.JPEG
# train/0/n01910747_16094.JPEG
# ...
# test/6/n07746186_22566.JPEG
# test/6/n07746186_25889.JPEG
# test/6/n07746186_25811.JPEG
# test/6/n07746186_29520.JPEG
# test/6/n07746186_20078.JPEG
# test/6/n07746186_24938.JPEG
# test/6/n07746186_26952.JPEG
# test/6/n07746186_20500.JPEG
# test/6/n07746186_28130.JPEG
# test/6/n07746186_30049.JPEG
# test/6/n07746186_24159.JPEG
# test/6/n07746186_30589.JPEG
# test/6/n07746186_28906.JPEG
# test/6/n07746186_27574.JPEG
# test/6/n07746186_30815.JPEG
# test/6/n07746186_26685.JPEG
# test/6/n07746186_22107.JPEG
# test/6/n07746186_19538.JPEG
# test/6/n07746186_25728.JPEG
# test/6/n07746186_30195.JPEG
# test/6/n07746186_23994.JPEG
# test/6/n07746186_25856.JPEG
# test/6/n07746186_19597.JPEG
# test/6/n07746186_19578.JPEG
# test/6/n07746186_19684.JPEG
# test/6/n07746186_27826.JPEG
# test/6/n07746186_24477.JPEG
# test/6/n07746186_28157.JPEG
# test/6/n07746186_19626.JPEG
# test/6/n07746186_27373.JPEG
# test/6/n07746186_29951.JPEG
# test/6/n07746186_29547.JPEG
# test/6/n07746186_26523.JPEG
# test/7/n04373704_10809.JPEG
# test/7/n04373704_7622.JPEG
# test/7/n04373704_7264.JPEG
# test/7/n04373704_5625.JPEG
# test/7/n04373704_8040.JPEG
# test/7/n04373704_5664.JPEG
# test/7/n04373704_6361.JPEG
# test/7/n04373704_6859.JPEG
# test/7/n04373704_6204.JPEG
# test/7/n04373704_6068.JPEG
# test/7/n04373704_6480.JPEG
# test/7/n04373704_6879.JPEG
# test/7/n04373704_8037.JPEG
# test/7/n04373704_5916.JPEG
# test/7/n04373704_6269.JPEG
# test/7/n04373704_6843.JPEG
# test/7/n04373704_5557.JPEG
# test/7/n04373704_6228.JPEG
# test/7/n04373704_6443.JPEG
# test/7/n04373704_6013.JPEG
# test/7/n04373704_7252.JPEG
# test/7/n04373704_5956.JPEG
# test/7/n04373704_6229.JPEG
# test/7/n04373704_10701.JPEG
# test/7/.DS_Store
# test/7/n04373704_8626.JPEG
# test/7/n04373704_10185.JPEG
# test/7/n04373704_5653.JPEG
# test/7/n04373704_10687.JPEG
# test/7/n04373704_6643.JPEG
# test/7/n04373704_6751.JPEG
# test/7/n04373704_6244.JPEG
# test/7/n04373704_10629.JPEG
# test/7/n04373704_8132.JPEG
# test/7/n04373704_6593.JPEG
# test/7/n04373704_6069.JPEG
# test/7/n04373704_5645.JPEG
# test/7/n04373704_6272.JPEG
# test/7/n04373704_5848.JPEG
# test/7/n04373704_5798.JPEG
# test/7/n04373704_6360.JPEG
# test/7/n04373704_7571.JPEG
# test/7/n04373704_7072.JPEG
# test/7/n04373704_8554.JPEG
# test/7/n04373704_7160.JPEG
# test/7/n04373704_10920.JPEG
# test/7/n04373704_6458.JPEG
# test/7/n04373704_7818.JPEG
# test/7/n04373704_8981.JPEG
# test/7/n04373704_10664.JPEG
# test/7/n04373704_5521.JPEG
# test/7/n04373704_9502.JPEG
# test/7/n04373704_6248.JPEG
# test/7/n04373704_10275.JPEG
# test/7/n04373704_6435.JPEG
# test/7/n04373704_8709.JPEG
# test/7/n04373704_10383.JPEG
# test/7/n04373704_5615.JPEG
# test/7/n04373704_7517.JPEG
# test/7/n04373704_10141.JPEG
# test/7/n04373704_8461.JPEG
# test/7/n04373704_5984.JPEG
# test/7/n04373704_6214.JPEG
# test/7/n04373704_9030.JPEG
# test/7/n04373704_8764.JPEG
# test/7/n04373704_6003.JPEG
# test/7/n04373704_7242.JPEG
# test/7/n04373704_6687.JPEG
# test/7/n04373704_8230.JPEG
# test/7/n04373704_6279.JPEG
# test/7/n04373704_5906.JPEG
# test/7/n04373704_5510.JPEG
# test/7/n04373704_5843.JPEG
# test/7/n04373704_8093.JPEG
# test/7/n04373704_9544.JPEG
# test/7/n04373704_9817.JPEG
# test/7/n04373704_5863.JPEG
# test/7/n04373704_7777.JPEG
# test/7/n04373704_6473.JPEG
# test/7/n04373704_6424.JPEG
# test/7/n04373704_6058.JPEG
# test/7/n04373704_8046.JPEG
# test/7/n04373704_9641.JPEG
# test/7/n04373704_8456.JPEG
# test/7/n04373704_5675.JPEG
# test/7/n04373704_6327.JPEG
# test/7/n04373704_5858.JPEG
# test/7/n04373704_9601.JPEG
# test/7/n04373704_10619.JPEG
# test/7/n04373704_6219.JPEG
# test/7/n04373704_7058.JPEG
# test/7/n04373704_6167.JPEG
# test/7/n04373704_9338.JPEG
# test/7/n04373704_6258.JPEG
# test/7/n04373704_9284.JPEG
# test/7/n04373704_6464.JPEG
# test/7/n04373704_5792.JPEG
# test/7/n04373704_6501.JPEG
# test/7/n04373704_6151.JPEG
# test/7/n04373704_5680.JPEG
# test/7/n04373704_7594.JPEG
# test/7/n04373704_10438.JPEG
# test/7/n04373704_5911.JPEG
# test/7/n04373704_9676.JPEG
# test/7/n04373704_6079.JPEG
# test/7/n04373704_5747.JPEG
# test/7/n04373704_5602.JPEG
# test/7/n04373704_6184.JPEG
# test/7/n04373704_8319.JPEG
# test/7/n04373704_6487.JPEG
# test/7/n04373704_5614.JPEG
# test/7/n04373704_5497.JPEG
# test/7/n04373704_10228.JPEG
# test/7/n04373704_9474.JPEG
# test/7/n04373704_6806.JPEG
# test/7/n04373704_6943.JPEG
# test/7/n04373704_5816.JPEG
# test/7/n04373704_10084.JPEG
# test/7/n04373704_6406.JPEG
# test/7/n04373704_7978.JPEG
# test/7/n04373704_7329.JPEG
# test/7/n04373704_8875.JPEG
# test/7/n04373704_5617.JPEG
# test/7/n04373704_7489.JPEG
# test/7/n04373704_10525.JPEG
# test/7/n04373704_6735.JPEG
# test/7/n04373704_10476.JPEG
# test/7/n04373704_9252.JPEG
# test/7/n04373704_7919.JPEG
# test/7/n04373704_8496.JPEG
# test/7/n04373704_5925.JPEG
# test/7/n04373704_5765.JPEG
# test/7/n04373704_6149.JPEG
# test/7/n04373704_6630.JPEG
# test/7/n04373704_10436.JPEG
# test/7/n04373704_5636.JPEG
# test/7/n04373704_8907.JPEG
# test/7/n04373704_5568.JPEG
# test/7/n04373704_6240.JPEG
# test/7/n04373704_6305.JPEG
# test/7/n04373704_6539.JPEG
# test/7/n04373704_6169.JPEG
# test/7/n04373704_10050.JPEG
# test/7/n04373704_10400.JPEG
# test/7/n04373704_10247.JPEG
# test/7/n04373704_7646.JPEG
# test/7/n04373704_9834.JPEG
# test/7/n04373704_5544.JPEG
# test/7/n04373704_6368.JPEG
# test/7/n04373704_8663.JPEG
# test/7/n04373704_6446.JPEG
# test/7/n04373704_9350.JPEG
# test/7/n04373704_9829.JPEG
# test/7/n04373704_5826.JPEG
# test/7/n04373704_6836.JPEG
# test/7/n04373704_6924.JPEG
# test/7/n04373704_6162.JPEG
# test/7/n04373704_9956.JPEG
# test/7/n04373704_5563.JPEG
# test/7/n04373704_9833.JPEG
# test/7/n04373704_7084.JPEG
# test/7/n04373704_5955.JPEG
# test/7/n04373704_7138.JPEG
# test/7/n04373704_6379.JPEG
# test/7/n04373704_5943.JPEG
# test/7/n04373704_6142.JPEG
# test/7/n04373704_6512.JPEG
# test/7/n04373704_9608.JPEG
# test/7/n04373704_7246.JPEG
# test/7/n04373704_9872.JPEG
# test/7/n04373704_6355.JPEG
# test/7/n04373704_5742.JPEG
# test/7/n04373704_5538.JPEG
# test/7/n04373704_7381.JPEG
# test/7/n04373704_10387.JPEG
# test/7/n04373704_6206.JPEG
# test/7/n04373704_9058.JPEG
# test/7/n04373704_7046.JPEG
# test/7/n04373704_7380.JPEG
# test/7/n04373704_7441.JPEG
# test/7/n04373704_10514.JPEG
# test/7/n04373704_5939.JPEG
# test/7/n04373704_6211.JPEG
# test/7/n04373704_10406.JPEG
# test/7/n04373704_10187.JPEG
# test/7/n04373704_9936.JPEG
# test/7/n04373704_6513.JPEG
# test/7/n04373704_7569.JPEG
# test/7/n04373704_7178.JPEG
# test/7/n04373704_6339.JPEG
# test/7/n04373704_5796.JPEG
# test/7/n04373704_6067.JPEG
# test/7/n04373704_8215.JPEG
# test/7/n04373704_6175.JPEG
# test/7/n04373704_5889.JPEG
# test/7/n04373704_5489.JPEG
# test/7/n04373704_6071.JPEG
# test/7/n04373704_6289.JPEG
# test/7/n04373704_5671.JPEG
# test/7/n04373704_5558.JPEG
# test/7/n04373704_5519.JPEG
# test/0/n01910747_914.JPEG
# test/0/n01910747_781.JPEG
# test/0/n01910747_943.JPEG
# test/0/n01910747_739.JPEG
# test/0/n01910747_1218.JPEG
# test/0/n01910747_1465.JPEG
# test/0/n01910747_996.JPEG
# test/0/n01910747_703.JPEG
# test/0/n01910747_1263.JPEG
# test/0/n01910747_1326.JPEG
# test/0/n01910747_980.JPEG
# test/0/n01910747_1234.JPEG
# test/0/n01910747_762.JPEG
# test/0/n01910747_1185.JPEG
# test/0/n01910747_735.JPEG
# test/0/n01910747_1081.JPEG
# test/0/n01910747_830.JPEG
# test/0/n01910747_1107.JPEG
# test/0/n01910747_1280.JPEG
# test/0/n01910747_1146.JPEG
# test/0/n01910747_1392.JPEG
# test/0/n01910747_963.JPEG
# test/0/n01910747_962.JPEG
# test/0/n01910747_1110.JPEG
# test/0/n01910747_1393.JPEG
# test/0/n01910747_935.JPEG
# test/0/n01910747_1014.JPEG
# test/0/n01910747_1278.JPEG
# test/0/.DS_Store
# test/0/n01910747_775.JPEG
# test/0/n01910747_688.JPEG
# test/0/n01910747_1203.JPEG
# test/0/n01910747_1079.JPEG
# test/0/n01910747_734.JPEG
# test/0/n01910747_714.JPEG
# test/0/n01910747_1059.JPEG
# test/0/n01910747_981.JPEG
# test/0/n01910747_1327.JPEG
# test/0/n01910747_893.JPEG
# test/0/n01910747_939.JPEG
# test/0/n01910747_755.JPEG
# test/0/n01910747_1018.JPEG
# test/0/n01910747_1366.JPEG
# test/0/n01910747_978.JPEG
# test/0/n01910747_738.JPEG
# test/0/n01910747_1029.JPEG
# test/0/n01910747_733.JPEG
# test/0/n01910747_676.JPEG
# test/0/n01910747_1091.JPEG
# test/0/n01910747_949.JPEG
# test/0/n01910747_1068.JPEG
# test/0/n01910747_772.JPEG
# test/0/n01910747_1195.JPEG
# test/0/n01910747_1228.JPEG
# test/0/n01910747_1382.JPEG
# test/0/n01910747_709.JPEG
# test/0/n01910747_836.JPEG
# test/0/n01910747_1290.JPEG
# test/0/n01910747_1269.JPEG
# test/0/n01910747_932.JPEG
# test/0/n01910747_1005.JPEG
# test/0/n01910747_877.JPEG
# test/0/n01910747_1052.JPEG
# test/0/n01910747_1402.JPEG
# test/0/n01910747_787.JPEG
# test/0/n01910747_1422.JPEG
# test/0/n01910747_695.JPEG
# test/0/n01910747_1434.JPEG
# test/0/n01910747_729.JPEG
# test/0/n01910747_841.JPEG
# test/0/n01910747_791.JPEG
# test/0/n01910747_894.JPEG
# test/0/n01910747_1320.JPEG
# test/0/n01910747_713.JPEG
# test/0/n01910747_968.JPEG
# test/0/n01910747_1321.JPEG
# test/0/n01910747_745.JPEG
# test/0/n01910747_1272.JPEG
# test/0/n01910747_1419.JPEG
# test/0/n01910747_840.JPEG
# test/0/n01910747_1198.JPEG
# test/0/n01910747_728.JPEG
# test/0/n01910747_1435.JPEG
# test/0/n01910747_1065.JPEG
# test/0/n01910747_1423.JPEG
# test/0/n01910747_1161.JPEG
# test/0/n01910747_856.JPEG
# test/0/n01910747_821.JPEG
# test/0/n01910747_876.JPEG
# test/0/n01910747_1012.JPEG
# test/0/n01910747_1291.JPEG
# test/0/n01910747_1229.JPEG
# test/0/n01910747_1252.JPEG
# test/0/n01910747_1205.JPEG
# test/0/n01910747_948.JPEG
# test/0/n01910747_1356.JPEG
# test/0/n01910747_988.JPEG
# test/0/n01910747_1284.JPEG
# test/0/n01910747_926.JPEG
# test/0/n01910747_1292.JPEG
# test/0/n01910747_1416.JPEG
# test/0/n01910747_1046.JPEG
# test/0/n01910747_1197.JPEG
# test/0/n01910747_1251.JPEG
# test/0/n01910747_1713.JPEG
# test/0/n01910747_727.JPEG
# test/0/n01910747_1093.JPEG
# test/0/n01910747_1705.JPEG
# test/0/n01910747_859.JPEG
# test/0/n01910747_766.JPEG
# test/0/n01910747_711.JPEG
# test/0/n01910747_746.JPEG
# test/0/n01910747_1334.JPEG
# test/0/n01910747_1226.JPEG
# test/0/n01910747_793.JPEG
# test/0/n01910747_1318.JPEG
# test/0/n01910747_1066.JPEG
# test/0/n01910747_947.JPEG
# test/0/n01910747_911.JPEG
# test/0/n01910747_784.JPEG
# test/0/n01910747_946.JPEG
# test/0/n01910747_1071.JPEG
# test/0/n01910747_680.JPEG
# test/0/n01910747_842.JPEG
# test/0/n01910747_792.JPEG
# test/0/n01910747_993.JPEG
# test/0/n01910747_839.JPEG
# test/0/n01910747_706.JPEG
# test/0/n01910747_1159.JPEG
# test/0/n01910747_751.JPEG
# test/0/n01910747_710.JPEG
# test/0/n01910747_1207.JPEG
# test/0/n01910747_1712.JPEG
# test/0/n01910747_1342.JPEG
# test/0/n01910747_771.JPEG
# test/0/n01910747_1694.JPEG
# test/0/n01910747_1047.JPEG
# test/0/n01910747_874.JPEG
# test/0/n01910747_1143.JPEG
# test/0/n01910747_1114.JPEG
# test/0/n01910747_823.JPEG
# test/0/n01910747_1373.JPEG
# test/0/n01910747_982.JPEG
# test/0/n01910747_1148.JPEG
# test/0/n01910747_869.JPEG
# test/0/n01910747_1220.JPEG
# test/0/n01910747_994.JPEG
# test/0/n01910747_1109.JPEG
# test/0/n01910747_900.JPEG
# test/0/n01910747_957.JPEG
# test/0/n01910747_812.JPEG
# test/0/n01910747_783.JPEG
# test/0/n01910747_1308.JPEG
# test/0/n01910747_916.JPEG
# test/0/n01910747_1164.JPEG
# test/0/n01910747_824.JPEG
# test/0/n01910747_1001.JPEG
# test/0/n01910747_1328.JPEG
# test/0/n01910747_1282.JPEG
# test/0/n01910747_865.JPEG
# test/0/n01910747_1152.JPEG
# test/0/n01910747_998.JPEG
# test/0/n01910747_1693.JPEG
# test/0/n01910747_1191.JPEG
# test/0/n01910747_849.JPEG
# test/0/n01910747_721.JPEG
# test/0/n01910747_1216.JPEG
# test/0/n01910747_1703.JPEG
# test/0/n01910747_1187.JPEG
# test/0/n01910747_1168.JPEG
# test/0/n01910747_761.JPEG
# test/0/n01910747_1305.JPEG
# test/0/n01910747_1169.JPEG
# test/0/n01910747_673.JPEG
# test/0/n01910747_1217.JPEG
# test/0/n01910747_1702.JPEG
# test/0/n01910747_1256.JPEG
# test/0/n01910747_1313.JPEG
# test/0/n01910747_848.JPEG
# test/0/n01910747_1368.JPEG
# test/0/n01910747_999.JPEG
# test/0/n01910747_1411.JPEG
# test/0/n01910747_864.JPEG
# test/0/n01910747_1153.JPEG
# test/0/n01910747_1329.JPEG
# test/0/n01910747_872.JPEG
# test/0/n01910747_1112.JPEG
# test/0/n01910747_1057.JPEG
# test/0/n01910747_782.JPEG
# test/0/n01910747_1077.JPEG
# test/0/n01910747_1427.JPEG
# test/0/n01910747_940.JPEG
# test/0/n01910747_690.JPEG
# test/0/n01910747_956.JPEG
# test/0/n01910747_1124.JPEG
# test/0/n01910747_844.JPEG
# test/0/n01910747_1221.JPEG
# test/0/n01910747_887.JPEG
# test/0/n01910747_1299.JPEG
# test/0/n01910747_983.JPEG
# test/0/n01910747_1372.JPEG
# test/9/n04273569_16253.JPEG
# test/9/n04273569_17045.JPEG
# test/9/n04273569_18037.JPEG
# test/9/n04273569_16615.JPEG
# test/9/n04273569_18109.JPEG
# test/9/n04273569_17356.JPEG
# test/9/n04273569_15916.JPEG
# test/9/n04273569_17747.JPEG
# test/9/n04273569_16290.JPEG
# test/9/n04273569_17878.JPEG
# test/9/n04273569_15845.JPEG
# test/9/n04273569_21767.JPEG
# test/9/n04273569_17340.JPEG
# test/9/n04273569_16551.JPEG
# test/9/n04273569_16228.JPEG
# test/9/n04273569_15865.JPEG
# test/9/n04273569_15998.JPEG
# test/9/n04273569_16064.JPEG
# test/9/n04273569_17458.JPEG
# test/9/n04273569_17073.JPEG
# test/9/n04273569_17531.JPEG
# test/9/n04273569_16766.JPEG
# test/9/n04273569_17989.JPEG
# test/9/n04273569_16048.JPEG
# test/9/n04273569_18057.JPEG
# test/9/n04273569_17121.JPEG
# test/9/n04273569_16008.JPEG
# test/9/.DS_Store
# test/9/n04273569_18041.JPEG
# test/9/n04273569_17320.JPEG
# test/9/n04273569_17377.JPEG
# test/9/n04273569_17623.JPEG
# test/9/n04273569_16679.JPEG
# test/9/n04273569_16100.JPEG
# test/9/n04273569_17880.JPEG
# test/9/n04273569_16511.JPEG
# test/9/n04273569_22330.JPEG
# test/9/n04273569_16546.JPEG
# test/9/n04273569_17455.JPEG
# test/9/n04273569_16839.JPEG
# test/9/n04273569_18077.JPEG
# test/9/n04273569_15868.JPEG
# test/9/n04273569_16252.JPEG
# test/9/n04273569_16259.JPEG
# test/9/n04273569_15971.JPEG
# test/9/n04273569_18093.JPEG
# test/9/n04273569_17223.JPEG
# test/9/n04273569_16131.JPEG
# test/9/n04273569_17235.JPEG
# test/9/n04273569_16058.JPEG
# test/9/n04273569_15859.JPEG
# test/9/n04273569_15789.JPEG
# test/9/n04273569_16222.JPEG
# test/9/n04273569_22511.JPEG
# test/9/n04273569_17297.JPEG
# test/9/n04273569_17917.JPEG
# test/9/n04273569_16982.JPEG
# test/9/n04273569_18070.JPEG
# test/9/n04273569_18089.JPEG
# test/9/n04273569_18066.JPEG
# test/9/n04273569_16078.JPEG
# test/9/n04273569_17813.JPEG
# test/9/n04273569_17429.JPEG
# test/9/n04273569_16146.JPEG
# test/9/n04273569_15855.JPEG
# test/9/n04273569_15906.JPEG
# test/9/n04273569_17487.JPEG
# test/9/n04273569_17983.JPEG
# test/9/n04273569_17652.JPEG
# test/9/n04273569_17255.JPEG
# test/9/n04273569_16501.JPEG
# test/9/n04273569_17428.JPEG
# test/9/n04273569_16096.JPEG
# test/9/n04273569_18067.JPEG
# test/9/n04273569_16716.JPEG
# test/9/n04273569_15771.JPEG
# test/9/n04273569_16274.JPEG
# test/9/n04273569_17977.JPEG
# test/9/n04273569_16167.JPEG
# test/9/n04273569_17326.JPEG
# test/9/n04273569_16472.JPEG
# test/9/n04273569_17849.JPEG
# test/9/n04273569_17388.JPEG
# test/9/n04273569_16433.JPEG
# test/9/n04273569_18753.JPEG
# test/9/n04273569_25813.JPEG
# test/9/n04273569_18013.JPEG
# test/9/n04273569_18044.JPEG
# test/9/n04273569_17671.JPEG
# test/9/n04273569_17128.JPEG
# test/9/n04273569_17997.JPEG
# test/9/n04273569_16543.JPEG
# test/9/n04273569_17217.JPEG
# test/9/n04273569_17145.JPEG
# test/9/n04273569_17283.JPEG
# test/9/n04273569_17057.JPEG
# test/9/n04273569_17684.JPEG
# test/9/n04273569_17942.JPEG
# test/9/n04273569_24633.JPEG
# test/9/n04273569_17943.JPEG
# test/9/n04273569_18065.JPEG
# test/9/n04273569_16407.JPEG
# test/9/n04273569_16391.JPEG
# test/9/n04273569_15769.JPEG
# test/9/n04273569_16515.JPEG
# test/9/n04273569_15786.JPEG
# test/9/n04273569_16329.JPEG
# test/9/n04273569_16295.JPEG
# test/9/n04273569_16692.JPEG
# test/9/n04273569_15972.JPEG
# test/9/n04273569_17559.JPEG
# test/9/n04273569_16309.JPEG
# test/9/n04273569_16519.JPEG
# test/9/n04273569_17522.JPEG
# test/9/n04273569_15773.JPEG
# test/9/n04273569_17968.JPEG
# test/9/n04273569_16292.JPEG
# test/9/n04273569_17179.JPEG
# test/9/n04273569_17196.JPEG
# test/9/n04273569_16441.JPEG
# test/9/n04273569_16050.JPEG
# test/9/n04273569_15892.JPEG
# test/9/n04273569_16586.JPEG
# test/9/n04273569_17801.JPEG
# test/9/n04273569_17786.JPEG
# test/9/n04273569_16949.JPEG
# test/9/n04273569_17964.JPEG
# test/9/n04273569_17134.JPEG
# test/9/n04273569_16861.JPEG
# test/9/n04273569_17909.JPEG
# test/9/n04273569_17661.JPEG
# test/9/n04273569_16461.JPEG
# test/9/n04273569_15922.JPEG
# test/9/n04273569_16175.JPEG
# test/9/n04273569_18079.JPEG
# test/9/n04273569_18096.JPEG
# test/9/n04273569_16499.JPEG
# test/9/n04273569_17322.JPEG
# test/9/n04273569_17498.JPEG
# test/9/n04273569_17477.JPEG
# test/9/n04273569_18014.JPEG
# test/9/n04273569_16270.JPEG
# test/9/n04273569_17932.JPEG
# test/9/n04273569_16362.JPEG
# test/9/n04273569_17787.JPEG
# test/9/n04273569_15997.JPEG
# test/9/n04273569_18063.JPEG
# test/9/n04273569_17617.JPEG
# test/9/n04273569_16456.JPEG
# test/9/n04273569_17494.JPEG
# test/9/n04273569_17882.JPEG
# test/9/n04273569_24927.JPEG
# test/9/n04273569_17178.JPEG
# test/9/n04273569_15903.JPEG
# all done

# %%
import os
data_path = '/content'
traindir = os.path.join(data_path + '/train')
print(traindir)
testdir = os.path.join(data_path + '/test')
print(testdir)
# Out:
# /content/train
# /content/test

# %%
'''data agumentaiton'''
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])

train_dataset = datasets.ImageFolder(
    traindir,
    transforms.Compose([
        transforms.Resize((256,256)),             
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        normalize,
    ]))

test_dataset = datasets.ImageFolder(
    testdir,
    transforms.Compose([
        transforms.Resize((224,224)),
        transforms.ToTensor(),
        normalize,
    ]))

# %%
trainloader = torch.utils.data.DataLoader(train_dataset,batch_size=16, shuffle=True)
testloader = torch.utils.data.DataLoader(test_dataset,batch_size=16, shuffle=True)

# %% [markdown]
# # 1 utils setup

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

def trainStep(network, criterion, optimizer, X, y):
	"""
	One training step of the network: forward prop + backprop + update parameters
	Return: (loss, accuracy) of current batch
	"""
	optimizer.zero_grad()
	outputs = network(X)
	loss = criterion(outputs, y)
	loss.backward()
	optimizer.step()
	accuracy = float(torch.sum(torch.argmax(outputs, dim=1) == y).item()) / y.shape[0]
	return np.mean(loss), accuracy

def getLossAccuracyOnDataset(network, dataset_loader, fast_device, criterion=None):
	"""
	Returns (loss, accuracy) of network on given dataset
	"""
	network.is_training = False
	accuracy = 0.0
	loss = 0.0
	dataset_size = 0
	for j, D in enumerate(dataset_loader, 0):
		X, y = D
		X = X.to(fast_device)
		y = y.to(fast_device)
		with torch.no_grad():
			pred = network(X)
			if criterion is not None:
				loss += criterion(pred, y) * y.shape[0]
			accuracy += torch.sum(torch.argmax(pred, dim=1) == y).item()
		dataset_size += y.shape[0]
	loss, accuracy = loss / dataset_size, accuracy / dataset_size
	network.is_training = True
	return loss, accuracy

def trainTeacherOnHparam(teacher_net, hparam, num_epochs, 
						train_loader, val_loader, 
						print_every=0, 
						fast_device=torch.device('cpu')):
	"""
	Trains teacher on given hyperparameters for given number of epochs; Pass val_loader=None when not required to validate for every epoch 
	Return: List of training loss, accuracy for each update calculated only on the batch; List of validation loss, accuracy for each epoch
	"""
	train_loss_list, train_acc_list, val_loss_list, val_acc_list = [], [], [], []
	train_losses = []
	train_acces = []
	teacher_net.dropout_input = hparam['dropout_input']
	teacher_net.dropout_hidden = hparam['dropout_hidden']
	criterion = nn.CrossEntropyLoss()
	optimizer = optim.SGD(teacher_net.parameters(), lr=hparam['lr'], momentum=hparam['momentum'], weight_decay=hparam['weight_decay'])
	lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=hparam['lr_decay'])
	for epoch in range(num_epochs):
		lr_scheduler.step()
		if epoch == 0:
			if val_loader is not None:
				val_loss, val_acc = getLossAccuracyOnDataset(teacher_net, val_loader, fast_device, criterion)
				val_loss_list.append(val_loss)
				val_acc_list.append(val_acc)
				print('epoch: %d validation loss: %.3f validation accuracy: %.3f' %(epoch, val_loss, val_acc))
		for i, data in enumerate(train_loader, 0):
			X, y = data
			X, y = X.to(fast_device), y.to(fast_device)
			loss, acc = trainStep(teacher_net, criterion, optimizer, X, y)
			train_loss_list.append(loss)
			train_acc_list.append(acc)

			if print_every > 0 and i % print_every == print_every - 1:
				print('[%d, %5d/%5d] train loss: %.3f train accuracy: %.3f' %
					  (epoch + 1, i + 1, len(train_loader), loss, acc))
		train_acces.append(np.mean(train_acc_list))
		train_losses.append(np.mean(train_acc_list))	
		if val_loader is not None:
			val_loss, val_acc = getLossAccuracyOnDataset(teacher_net, val_loader, fast_device, criterion)
			val_loss_list.append(val_loss)
			val_acc_list.append(val_acc)
			print('epoch: %d validation loss: %.3f validation accuracy: %.3f' %(epoch + 1, val_loss, val_acc))
	return {'train_loss': train_losses, 
			'train_acc': train_acces}

def studentTrainStep(teacher_net, student_net, studentLossFn, optimizer, X, y, T, alpha):
	"""
	One training step of student network: forward prop + backprop + update parameters
	Return: (loss, accuracy) of current batch
	"""
	optimizer.zero_grad()
	teacher_pred = None
	if (alpha > 0):
		with torch.no_grad():
			teacher_pred = teacher_net(X) 
	student_pred = student_net(X)
	# print(student_pred)
	loss = studentLossFn(teacher_pred, student_pred, y, T, alpha)
	loss.backward()
	torch.nn.utils.clip_grad_norm_(student_net.parameters(), 20)
	optimizer.step()
	accuracy = float(torch.sum(torch.argmax(student_pred, dim=1) == y).item()) / y.shape[0]
	return loss, accuracy

def trainStudentOnHparam(teacher_net, student_net, hparam, num_epochs, 
						train_loader, val_loader, 
						print_every=0, 
						fast_device=torch.device('cpu')):
	"""
	Trains teacher on given hyperparameters for given number of epochs; Pass val_loader=None when not required to validate for every epoch
	Return: List of training loss, accuracy for each update calculated only on the batch; List of validation loss, accuracy for each epoch
	"""
	train_loss_list, train_acc_list, val_acc_list = [], [], []
	T = hparam['T']
	alpha = hparam['alpha']
	student_net.dropout_input = hparam['dropout_input']
	student_net.dropout_hidden = hparam['dropout_hidden']
	optimizer = optim.SGD(student_net.parameters(), lr=hparam['lr'], momentum=hparam['momentum'], weight_decay=hparam['weight_decay'])
	lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=hparam['lr_decay'])
	BASE_PATH = '/gdrive/My Drive/colab_files/caifar10_alexnet/'

	def studentLossFn(teacher_pred, student_pred, y, T, alpha):
		"""
		Loss function for student network: Loss = alpha * (distillation loss with soft-target) + (1 - alpha) * (cross-entropy loss with true label)
		Return: loss
		"""
		if (alpha > 0):
			loss = F.kl_div(F.log_softmax(student_pred / T, dim=1), F.softmax(teacher_pred / T, dim=1), reduction='batchmean') * (T ** 2) * alpha + F.cross_entropy(student_pred, y) * (1 - alpha)
		else:
			loss = F.cross_entropy(student_pred, y)
		return loss

	for epoch in range(num_epochs):
		lr_scheduler.step()
		epoch_loss = 0

		if epoch == 0:
			if val_loader is not None:
				_, val_acc = getLossAccuracyOnDataset(student_net, val_loader, fast_device)
				val_acc_list.append(val_acc)
				print('epoch: %d validation accuracy: %.3f' %(epoch, val_acc))
		for i, batch in enumerate(train_loader, 0):
			imgs = batch['image']
			true_masks = batch['mask']
			assert imgs.shape[1] == net.n_channels, \
					f'Network has been defined with {net.n_channels} input channels, ' \
					f'but loaded images have {imgs.shape[1]} channels. Please check that ' \
					'the images are loaded correctly.'

			imgs = imgs.to(device=device, dtype=torch.float32)
			mask_type = torch.float32 if net.n_classes == 1 else torch.long
			true_masks = true_masks.to(device=device, dtype=mask_type)

			masks_pred = net(imgs)
			loss = criterion(masks_pred, true_masks)
			epoch_loss += loss.item()
			optimizer.zero_grad()
			loss.backward()
			nn.utils.clip_grad_value_(net.parameters(), 20)
			optimizer.step()
			# X, y = data
			# X, y = X.to(fast_device), y.to(fast_device)
			# loss, acc = studentTrainStep(teacher_net, student_net, studentLossFn, optimizer, X, y, T, alpha)
			train_loss_list.append(loss)
			train_acc_list.append(acc)
			if print_every > 0 and i % print_every == print_every - 1:
			  print('[%d, %5d/%5d] train loss: %.3f train accuracy: %.3f' %
			    (epoch + 1, i + 1, len(train_loader), loss, acc))
	
		if val_loader is not None:
			_, val_acc = getLossAccuracyOnDataset(student_net, val_loader, fast_device)
			val_acc_list.append(val_acc)
			print('epoch: %d validation accuracy: %.3f' %(epoch + 1, val_acc))
	
	return {'train_loss': train_loss_list, 
			'train_acc': train_acc_list, 
			'val_acc': val_acc_list}

def hparamToString(hparam):
	"""
	Convert hparam dictionary to string with deterministic order of attribute of hparam in output string
	"""
	hparam_str = ''
	for k, v in sorted(hparam.items()):
		hparam_str += k + '=' + str(v) + ', '
	return hparam_str[:-2]

def hparamDictToTuple(hparam):
	"""
	Convert hparam dictionary to tuple with deterministic order of attribute of hparam in output tuple
	"""
	hparam_tuple = [v for k, v in sorted(hparam.items())]
	return tuple(hparam_tuple)

def getTrainMetricPerEpoch(train_metric, updates_per_epoch):
	"""
	Smooth the training metric calculated for each batch of training set by averaging over batches in an epoch
	Input: List of training metric calculated for each batch
	Output: List of training matric averaged over each epoch
	"""
	train_metric_per_epoch = []
	temp_sum = 0.0
	for i in range(len(train_metric)):
		temp_sum += train_metric[i]
		if (i % updates_per_epoch == updates_per_epoch - 1):
			train_metric_per_epoch.append(temp_sum / updates_per_epoch)
			temp_sum = 0.0

	return train_metric_per_epoch

# %% [markdown]
# # 2 network

# %%
import torch
from torch import nn

class spectral_pool_layer(nn.Module):
  def __init__(self,filter_size=3,freq_dropout_lower_bound=None,freq_dropout_upper_bound=None,train_phase = False ):
    super(spectral_pool_layer,self).__init__()
    # assert only 1 dimension passed for filter size
    assert isinstance(filter_size, int)
    # input_shape = x.shape
    # assert len(input_shape) == 4
    # _, _, H, W = input_shape
    # assert H == W

    self.filter_size = filter_size
    self.freq_dropout_lower_bound = freq_dropout_lower_bound
    self.freq_dropout_upper_bound = freq_dropout_upper_bound
    self.activation = F
    self.train_phase = train_phase 
  
  def forward(self,x):
    # Compute the Fourier transform of the image
    im_fft = torch.rfft(x,2,onesided = False)

    # Truncate the spectrum
    im_transformed = self._common_spectral_pool(im_fft, self.filter_size)

    if ( self.freq_dropout_lower_bound is not None and self.freq_dropout_upper_bound is not None):
      def true_fn():
      		tf_random_cutoff = tf.random_uniform(
						[],
						freq_dropout_lower_bound,
						freq_dropout_upper_bound
					)
      		dropout_mask = _frequency_dropout_mask(
						filter_size,
						tf_random_cutoff
					)
      		return im_transformed * dropout_mask

				# In the testing phase, return the truncated frequency
				# matrix unchanged.
      def false_fn():
      		return im_transformed
      im_downsampled = tf.cond(
					self.train_phase,
					true_fn=true_fn,
					false_fn=false_fn
				)
      im_out = torch.irfft(im_downsampled,2, onesided=False)
		
    else:
      im_out = torch.irfft(im_transformed,2, onesided=False)
    
    if self.activation is not None:
      		cell_out = self.activation.relu(im_out)
    else:
      cell_out = im_out
    return cell_out

  def _common_spectral_pool(self,images, filter_size):
    assert len(images.shape) == 5
    assert filter_size >= 3
	
    if filter_size % 2 == 1:
      n = int((filter_size-1)/2)
      top_left = images[:, :, :n+1, :n+1]
      top_right = images[:, :, :n+1, -n:]
      bottom_left = images[:, :, -n:, :n+1]
      bottom_right = images[:, :, -n:, -n:]
      top_combined = torch.cat([top_left, top_right], axis=-2)
      # print(top_combined.shape)
      bottom_combined = torch.cat([bottom_left, bottom_right], axis=-2)
      # print(bottom_combined.shape)
      all_together = torch.cat([top_combined, bottom_combined], axis=-3)
      return all_together

# %%
import torch
import numpy as np
import torch.nn.functional as F
from torch.nn.parameter import Parameter
from scipy import signal
import scipy
from torch import nn
import time

def dft_conv(imgR,imgIm,kernelR,kernelIm):

    # Fast complex multiplication
    ac = torch.mul(kernelR, imgR)
    bd = torch.mul(kernelIm, imgIm)
    
    ab_cd = torch.mul(torch.add(kernelR, kernelIm), torch.add(imgR, imgIm))
    # print(ab_cd.sum(1)[0,0,:,:])
    imgsR = ac - bd
    imgsIm = ab_cd - ac - bd

    # Sum over in channels
    imgsR = imgsR.sum(1)
    imgsIm = imgsIm.sum(1)


    return imgsR,imgsIm

class FFT_Conv_Layer(nn.Module):

    def __init__(self,imgSize,inCs,outCs,imagDim,filtSize,cuda=False):

        super(FFT_Conv_Layer, self).__init__()
        self.filts = np.random.normal(0,0.01,(1,inCs,outCs,filtSize,filtSize,imagDim))
        self.imgSize = imgSize
        self.filtSize = np.size(self.filts,4)

        if cuda:
            self.filts = torch.from_numpy(self.filts).type(torch.float32).cuda()
            self.filts = Parameter(self.filts)
        

    def forward(self,imgs):

        # Pad and transform the image
        # Pad arg = (last dim pad left side, last dim pad right side, 2nd last dim left side, etc..)
        # imgs = torch.randn(batchSize,inCs,1,imgSize, imgSize,imagDim).cuda()
        imgs = imgs.unsqueeze(2)
        imgs = imgs.unsqueeze(5)

        imgs = F.pad(imgs, (0, 0, 0, self.filtSize - 1, 0,self.filtSize - 1))
        imgs = imgs.squeeze(5)

        imgs = torch.rfft(imgs,2,onesided= False)
        # print(imgs.shape)

        # Extract the real and imaginary parts
        imgsR = imgs[:, :, :, :, :, 0]
        imgsIm = imgs[:, :, :, :, :, 1]
        

        # Pad and transform the filters
        filts = F.pad(self.filts, (0, 0, 0, self.imgSize - 1, 0, self.imgSize - 1))

        filts = torch.fft(filts, 2)

        # Extract the real and imaginary parts
        filtR = filts[:, :, :, :, :, 0]
        filtIm = filts[:, :, :, :, :, 1]

        # Do element wise complex multiplication
        imgsR, imgsIm = dft_conv(imgsR,imgsIm,filtR,filtIm)

        # Add dim to concat over
        imgsR = imgsR.unsqueeze(4)
        imgsIm = imgsIm.unsqueeze(4)

        # Concat the real and imaginary again then IFFT
        imgs = torch.cat((imgsR,imgsIm),-1)
        #print("1",imgs.shape)
        imgs = torch.ifft(imgs,2)
        #print("2",imgs.shape)

        # Filter and imgs were real so imag should be ~0
        imgs = imgs[:,:,1:-1,1:-1,0]
        #print("3",imgs.shape)

        return imgs

# %%
class StudentNetwork_noRelu(nn.Module):
  def __init__(self):
    super(StudentNetwork_noRelu,self).__init__()
    self.conv1 = FFT_Conv_Layer(imgSize = 224 ,inCs = 3,outCs = 32,imagDim =2,filtSize = 3,cuda=True)
    # self.conv1 = nn.Conv2d(3,64, kernel_size=11,stride = 4,padding = 2)
    self.conv2 = FFT_Conv_Layer(imgSize = 113 ,inCs = 32,outCs =64,imagDim =2,filtSize = 3,cuda=True)
    self.conv3 = FFT_Conv_Layer(imgSize = 27 ,inCs = 64,outCs = 256,imagDim =2,filtSize = 3,cuda=True)
    self.fc1 = nn.Linear(9216, 512)
    self.fc2 = nn.Linear(512,256)
    self.fc3 = nn.Linear(256,10)
    self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
    self.dropout_input = 0.5
    self.dropout_hidden = 0.5
    self.is_training = True
    self.avepool = nn.AdaptiveAvgPool2d((6,6))
    self.m = nn.LogSoftmax(dim=1)
    self.max_113 = spectral_pool_layer(113)
    self.max_27 = spectral_pool_layer(27)

    
  
  def forward(self,x):
    #print(x.shape)
    forw = self.conv1(x)
    # print(forw.shape)
    #forw = self.max_113(torch.square(self.conv1(x)))
    #forw = self.max_27(torch.square(self.conv2(forw)))
    forw = self.max_113(self.conv1(x))
    forw = self.max_27(self.conv2(forw))
    # # print(forw.shape)
    forw = self.conv3(forw)
    # # print(forw.shape)
    forw = self.maxpool(forw)
    forw = self.avepool(forw)
    forw = forw.view(-1,9216)
    forw = F.dropout(forw, p=self.dropout_input, training=self.is_training)
    forw = F.dropout(self.fc1(forw), p=self.dropout_hidden, training=self.is_training)
    forw = F.relu(forw)
    forw = self.fc2(forw)
    forw = F.relu(forw)
    forw = self.fc3(forw)
    return self.m(forw)

# %% [markdown]
# time test

# %%
inputs = torch.rand([1,3,224,224],dtype= torch.float)
print(inputs.shape)
inputs = inputs.to("cuda")
model = StudentNetwork_noRelu()
model.to('cuda')


import datetime
starttime = datetime.datetime.now()
#long running
for i in range(100):
  model.forward(inputs)

endtime = datetime.datetime.now()
print (endtime - starttime)
# Out:
# torch.Size([1, 3, 224, 224])
# 0:00:04.546426

# %% [markdown]
# # 3 pre-training for students

# %%
device = 'cuda'
model = StudentNetwork_noRelu()
# model = teacher_net
criterion = nn.NLLLoss()
#optimizer = optim.Adam(model.parameters(), lr=0.003)
optimizer = optim.SGD(model.parameters(), lr=0.003)
model.to(device)

from tqdm import tqdm

traininglosses = []
testinglosses = []
testaccuracy = []
totalsteps = []
epochs = 50
steps = 0
running_loss = 0
print_every = 100
for epoch in range(epochs):
    for inputs, labels in trainloader:
        steps += 1
        # Move input and label tensors to the default device
        inputs, labels = inputs.to(device), labels.to(device)
        print(inputs.shape)
        
        optimizer.zero_grad()
        
        logps = model.forward(inputs)
        loss = criterion(logps, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        
        if steps % print_every == 0:
            test_loss = 0
            accuracy = 0
            model.eval()
            with torch.no_grad():
                for inputs, labels in testloader:
                    inputs, labels = inputs.to(device), labels.to(device)
                    logps = model.forward(inputs)
                    batch_loss = criterion(logps, labels)
                    
                    test_loss += batch_loss.item()
                    
                    # Calculate accuracy
                    ps = torch.exp(logps)
                    top_p, top_class = ps.topk(1, dim=1)
                    equals = top_class == labels.view(*top_class.shape)
                    accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
            
            traininglosses.append(running_loss/print_every)
            testinglosses.append(test_loss/len(testloader))
            testaccuracy.append(accuracy/len(testloader))
            totalsteps.append(steps)
            print(f"Device {device}.."
                  f"Epoch {epoch+1}/{epochs}.. "
                  f"Step {steps}.. "
                  f"Train loss: {running_loss/print_every:.3f}.. "
                  f"Test loss: {test_loss/len(testloader):.3f}.. "
                  f"Test accuracy: {accuracy/len(testloader):.3f}")
            running_loss = 0
            model.train()
# Out:
# torch.Size([16, 3, 224, 224])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-383737ed4d6d> in <module>()
#      26         optimizer.zero_grad()
#      27
# ---> 28         logps = model.forward(inputs)
#      29         loss = criterion(logps, labels)
#      30         loss.backward()
#
# <ipython-input-10-bb81470c3eaa> in forward(self, x)
#      22   def forward(self,x):
#      23     # print(x.shape)
# ---> 24     forw = self.conv1(x)
#      25     # print(forw.shape)
#      26     forw = self.max_113(self.conv1(x))
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# <ipython-input-8-cef3a5dad8ee> in forward(self, imgs)
#      71
#      72         # Do element wise complex multiplication
# ---> 73         imgsR, imgsIm = dft_conv(imgsR,imgsIm,filtR,filtIm)
#      74
#      75         # Add dim to concat over
#
# <ipython-input-8-cef3a5dad8ee> in dft_conv(imgR, imgIm, kernelR, kernelIm)
#      22     # imgsR = imgsR.sum(1)
#      23     # imgsIm = imgsIm.sum(1)
# ---> 24     _,_,H,W = imgsR.shape
#      25     imgsR = imgsR.view(-1,H,W)
#      26     imgsIm = imgsIm.view(-1,H,W)
#
# ValueError: too many values to unpack (expected 4)

# %% [markdown]
# # 4 load the pretrain student model

# %%
import torch
pretrained_dict = torch.load(BASE_PATH+'/net_params.pkl')
net = StudentNetwork_noRelu()
net.load_state_dict(pretrained_dict) 
device = "cuda"
net.to(device)

# %%
_, test_accuracy = getLossAccuracyOnDataset(net, testloader, device)
print('teacher test accuracy (w distillation): ', test_accuracy)
# Out:
# teacher test accuracy (w distillation):  0.7272727272727273

# %%
for name, param in net.named_parameters():
  if ("conv" in name):
    param.requires_grad = False
  else:
    param.requires_grad = True

# %%
for name, param in net.named_parameters():
  print(name,param.requires_grad)
# Out:
# conv1.filts False
# conv2.filts False
# conv3.filts False
# fc1.weight True
# fc1.bias True
# fc2.weight True
# fc2.bias True
# fc3.weight True
# fc3.bias True

# %% [markdown]
# # 5 load the teacher model

# %%
model = torch.load(BASE_PATH +"/teacher.pkl")
model
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (fc1): Linear(in_features=9216, out_features=1024, bias=True)
#     (relu1): ReLU()
#     (fc2): Linear(in_features=1024, out_features=256, bias=True)
#     (relu2): ReLU()
#     (fc3): Linear(in_features=256, out_features=10, bias=True)
#     (output): LogSoftmax(dim=1)
#   )
# )

# %%
x = torch.zeros([10,3,224,224])
print(x.shape)
model.features[0:11](x.cuda()).shape
# Out:
# torch.Size([10, 3, 224, 224])
# torch.Size([10, 256, 13, 13])

# %%
_, test_accuracy = getLossAccuracyOnDataset(model, testloader, "cuda")
print('teacher test accuracy (w distillation): ', test_accuracy)
# Out:
# teacher test accuracy (w distillation):  0.939572192513369

# %% [markdown]
# # 6 knowledge distillation

# %%
import numpy as np
import math

# %matplotlib inline
import matplotlib.pyplot as plt

import pickle
import argparse
import time
import itertools
from copy import deepcopy
import os

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
    
# %load_ext autoreload
# %autoreload 2
num_epochs = 50
print_every = 200
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
temperatures = [10]
# trade-off between soft-target (st) cross-entropy and true-target (tt) cross-entropy;
# loss = alpha * st + (1 - alpha) * tt
alphas = [0.5]
learning_rates = [0.0001]
learning_rate_decays = [0.95]
weight_decays = [1e-5]
momentums = [0.9]
dropout_probabilities = [(0,0)]
hparams_list = []
for hparam_tuple in itertools.product(alphas, temperatures, dropout_probabilities, weight_decays, learning_rate_decays, 
                                        momentums, learning_rates):
    hparam = {}
    hparam['alpha'] = hparam_tuple[0]
    hparam['T'] = hparam_tuple[1]
    hparam['dropout_input'] = hparam_tuple[2][0]
    hparam['dropout_hidden'] = hparam_tuple[2][1]
    hparam['weight_decay'] = hparam_tuple[3]
    hparam['lr_decay'] = hparam_tuple[4]
    hparam['momentum'] = hparam_tuple[5]
    hparam['lr'] = hparam_tuple[6]
    hparams_list.append(hparam)
print(hparams_list)
# Out:
# [{'alpha': 0.5, 'T': 10, 'dropout_input': 0, 'dropout_hidden': 0, 'weight_decay': 1e-05, 'lr_decay': 0.95, 'momentum': 0.9, 'lr': 0.0001}]

# %%
device = torch.device("cuda")
use_gpu = True
# Ensure reproducibility
def reproducibilitySeed():
    """
    Ensure reproducibility of results; Seeds to 0
    """
    torch_init_seed = 0
    torch.manual_seed(torch_init_seed)
    numpy_init_seed = 0
    np.random.seed(numpy_init_seed)
    if use_gpu:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

reproducibilitySeed()

# %%
model.to(device)
results_distill = {}

for hparam in hparams_list:
    print('Training with hparams' + hparamToString(hparam))
    reproducibilitySeed()
    student_net = student_net
    hparam_tuple = hparamDictToTuple(hparam)
    results_distill[hparam_tuple] = trainStudentOnHparam(model, student_net, hparam, num_epochs, 
                                                                trainloader, testloader, 
                                                                print_every=print_every, 
                                                                fast_device = device)
# Out:
# Training with hparamsT=10, alpha=0.5, dropout_hidden=0, dropout_input=0, lr=0.0001, lr_decay=0.95, momentum=0.9, weight_decay=1e-05
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:123: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# epoch: 0 validation accuracy: 0.780
# [1,   200/  625] train loss: 2.211 train accuracy: 0.688
# [1,   400/  625] train loss: 0.879 train accuracy: 0.812
# [1,   600/  625] train loss: 1.973 train accuracy: 0.688
# epoch: 1 validation accuracy: 0.788
# [2,   200/  625] train loss: 1.973 train accuracy: 0.938
# [2,   400/  625] train loss: 3.238 train accuracy: 0.750
# [2,   600/  625] train loss: 2.112 train accuracy: 0.875
# epoch: 2 validation accuracy: 0.787
# [3,   200/  625] train loss: 1.870 train accuracy: 0.938
# [3,   400/  625] train loss: 3.349 train accuracy: 1.000
# [3,   600/  625] train loss: 2.072 train accuracy: 0.875
# epoch: 3 validation accuracy: 0.789
# [4,   200/  625] train loss: 4.293 train accuracy: 0.875
# [4,   400/  625] train loss: 3.130 train accuracy: 0.750
# [4,   600/  625] train loss: 1.857 train accuracy: 0.688
# epoch: 4 validation accuracy: 0.787
# [5,   200/  625] train loss: 3.130 train accuracy: 0.750
# [5,   400/  625] train loss: 1.783 train accuracy: 0.750
# [5,   600/  625] train loss: 2.141 train accuracy: 0.812
# epoch: 5 validation accuracy: 0.791
# [6,   200/  625] train loss: 1.527 train accuracy: 0.938
# [6,   400/  625] train loss: 1.504 train accuracy: 0.875
# [6,   600/  625] train loss: 2.429 train accuracy: 0.875
# epoch: 6 validation accuracy: 0.796
# [7,   200/  625] train loss: 3.008 train accuracy: 0.625
# [7,   400/  625] train loss: 2.243 train accuracy: 0.938
# [7,   600/  625] train loss: 1.504 train accuracy: 0.875
# epoch: 7 validation accuracy: 0.796
# [8,   200/  625] train loss: 2.502 train accuracy: 0.750
# [8,   400/  625] train loss: 2.068 train accuracy: 0.875
# [8,   600/  625] train loss: 1.052 train accuracy: 0.938
# epoch: 8 validation accuracy: 0.795
# [9,   200/  625] train loss: 2.097 train accuracy: 0.812
# [9,   400/  625] train loss: 2.879 train accuracy: 0.812
# [9,   600/  625] train loss: 2.787 train accuracy: 0.812
# epoch: 9 validation accuracy: 0.796
# [10,   200/  625] train loss: 1.678 train accuracy: 0.812
# [10,   400/  625] train loss: 2.261 train accuracy: 0.750
# [10,   600/  625] train loss: 2.070 train accuracy: 0.875
# epoch: 10 validation accuracy: 0.797
# [11,   200/  625] train loss: 2.810 train accuracy: 0.938
# [11,   400/  625] train loss: 3.983 train accuracy: 0.875
# [11,   600/  625] train loss: 1.252 train accuracy: 0.875
# epoch: 11 validation accuracy: 0.799
# [12,   200/  625] train loss: 1.060 train accuracy: 1.000
# [12,   400/  625] train loss: 1.544 train accuracy: 0.625
# [12,   600/  625] train loss: 2.006 train accuracy: 0.812
# epoch: 12 validation accuracy: 0.797
# [13,   200/  625] train loss: 2.085 train accuracy: 0.812
# [13,   400/  625] train loss: 2.279 train accuracy: 1.000
# [13,   600/  625] train loss: 5.042 train accuracy: 0.750
# epoch: 13 validation accuracy: 0.795
# [14,   200/  625] train loss: 1.378 train accuracy: 0.812
# [14,   400/  625] train loss: 1.355 train accuracy: 0.875
# [14,   600/  625] train loss: 2.212 train accuracy: 0.812
# epoch: 14 validation accuracy: 0.798
# [15,   200/  625] train loss: 2.214 train accuracy: 0.812
# [15,   400/  625] train loss: 1.935 train accuracy: 0.875
# [15,   600/  625] train loss: 2.027 train accuracy: 0.875
# epoch: 15 validation accuracy: 0.797
# [16,   200/  625] train loss: 2.287 train accuracy: 0.875
# [16,   400/  625] train loss: 1.076 train accuracy: 0.938
# [16,   600/  625] train loss: 2.042 train accuracy: 0.938
# epoch: 16 validation accuracy: 0.795
# [17,   200/  625] train loss: 3.343 train accuracy: 0.812
# [17,   400/  625] train loss: 2.409 train accuracy: 0.750
# [17,   600/  625] train loss: 1.842 train accuracy: 0.812
# epoch: 17 validation accuracy: 0.796
# [18,   200/  625] train loss: 1.328 train accuracy: 0.875
# [18,   400/  625] train loss: 1.821 train accuracy: 0.812
# [18,   600/  625] train loss: 1.671 train accuracy: 0.875
# epoch: 18 validation accuracy: 0.795
# [19,   200/  625] train loss: 2.127 train accuracy: 0.938
# [19,   400/  625] train loss: 2.965 train accuracy: 0.625
# [19,   600/  625] train loss: 1.849 train accuracy: 0.688
# epoch: 19 validation accuracy: 0.798
# [20,   200/  625] train loss: 1.677 train accuracy: 0.812
# [20,   400/  625] train loss: 1.681 train accuracy: 0.938
# [20,   600/  625] train loss: 1.925 train accuracy: 0.875
# epoch: 20 validation accuracy: 0.793
# [21,   200/  625] train loss: 2.443 train accuracy: 0.812
# [21,   400/  625] train loss: 1.518 train accuracy: 0.875
# [21,   600/  625] train loss: 2.301 train accuracy: 0.688
# epoch: 21 validation accuracy: 0.799
# [22,   200/  625] train loss: 1.791 train accuracy: 0.812
# [22,   400/  625] train loss: 1.806 train accuracy: 0.812
# [22,   600/  625] train loss: 1.231 train accuracy: 0.875
# epoch: 22 validation accuracy: 0.797
# [23,   200/  625] train loss: 2.716 train accuracy: 0.812
# [23,   400/  625] train loss: 2.250 train accuracy: 1.000
# [23,   600/  625] train loss: 4.268 train accuracy: 0.938
# epoch: 23 validation accuracy: 0.798
# [24,   200/  625] train loss: 2.374 train accuracy: 0.625
# [24,   400/  625] train loss: 3.208 train accuracy: 0.875
# [24,   600/  625] train loss: 1.654 train accuracy: 0.875
# epoch: 24 validation accuracy: 0.801
# [25,   200/  625] train loss: 2.743 train accuracy: 0.812
# [25,   400/  625] train loss: 1.449 train accuracy: 1.000
# [25,   600/  625] train loss: 1.688 train accuracy: 0.875
# epoch: 25 validation accuracy: 0.799
# [26,   200/  625] train loss: 1.845 train accuracy: 0.812
# [26,   400/  625] train loss: 3.207 train accuracy: 0.625
# [26,   600/  625] train loss: 1.301 train accuracy: 0.938
# epoch: 26 validation accuracy: 0.799
# [27,   200/  625] train loss: 1.793 train accuracy: 0.688
# [27,   400/  625] train loss: 2.098 train accuracy: 0.750
# [27,   600/  625] train loss: 1.784 train accuracy: 0.750
# epoch: 27 validation accuracy: 0.799
# [28,   200/  625] train loss: 1.446 train accuracy: 0.875
# [28,   400/  625] train loss: 2.396 train accuracy: 0.875
# [28,   600/  625] train loss: 1.231 train accuracy: 0.875
# epoch: 28 validation accuracy: 0.798
# [29,   200/  625] train loss: 1.613 train accuracy: 0.812
# [29,   400/  625] train loss: 1.273 train accuracy: 0.938
# [29,   600/  625] train loss: 0.835 train accuracy: 0.938
# epoch: 29 validation accuracy: 0.801
# [30,   200/  625] train loss: 1.590 train accuracy: 0.812
# [30,   400/  625] train loss: 1.865 train accuracy: 0.750
# [30,   600/  625] train loss: 2.096 train accuracy: 0.875
# epoch: 30 validation accuracy: 0.800
# [31,   200/  625] train loss: 1.730 train accuracy: 0.875
# [31,   400/  625] train loss: 2.030 train accuracy: 0.875
# [31,   600/  625] train loss: 1.641 train accuracy: 0.750
# epoch: 31 validation accuracy: 0.801
# [32,   200/  625] train loss: 2.153 train accuracy: 0.938
# [32,   400/  625] train loss: 1.673 train accuracy: 0.938
# [32,   600/  625] train loss: 1.132 train accuracy: 0.812
# epoch: 32 validation accuracy: 0.801
# [33,   200/  625] train loss: 2.851 train accuracy: 0.938
# [33,   400/  625] train loss: 2.136 train accuracy: 1.000
# [33,   600/  625] train loss: 1.477 train accuracy: 0.750
# epoch: 33 validation accuracy: 0.799
# [34,   200/  625] train loss: 0.954 train accuracy: 0.938
# [34,   400/  625] train loss: 1.297 train accuracy: 1.000
# [34,   600/  625] train loss: 1.708 train accuracy: 0.812
# epoch: 34 validation accuracy: 0.799
# [35,   200/  625] train loss: 2.052 train accuracy: 0.812
# [35,   400/  625] train loss: 2.474 train accuracy: 0.875
# [35,   600/  625] train loss: 1.647 train accuracy: 0.688
# epoch: 35 validation accuracy: 0.799
# [36,   200/  625] train loss: 2.474 train accuracy: 0.812
# [36,   400/  625] train loss: 2.125 train accuracy: 0.812
# [36,   600/  625] train loss: 1.895 train accuracy: 0.875
# epoch: 36 validation accuracy: 0.799
# [37,   200/  625] train loss: 1.755 train accuracy: 0.812
# [37,   400/  625] train loss: 2.737 train accuracy: 0.625
# [37,   600/  625] train loss: 2.357 train accuracy: 0.875
# epoch: 37 validation accuracy: 0.799
# [38,   200/  625] train loss: 4.116 train accuracy: 0.750
# [38,   400/  625] train loss: 2.059 train accuracy: 0.625
# [38,   600/  625] train loss: 3.236 train accuracy: 1.000
# epoch: 38 validation accuracy: 0.801
# [39,   200/  625] train loss: 1.068 train accuracy: 0.750
# [39,   400/  625] train loss: 2.222 train accuracy: 0.875
# [39,   600/  625] train loss: 2.276 train accuracy: 0.875
# epoch: 39 validation accuracy: 0.801
# [40,   200/  625] train loss: 1.978 train accuracy: 0.750
# [40,   400/  625] train loss: 1.223 train accuracy: 0.938
# [40,   600/  625] train loss: 2.586 train accuracy: 0.875
# epoch: 40 validation accuracy: 0.801
# [41,   200/  625] train loss: 1.533 train accuracy: 0.875
# [41,   400/  625] train loss: 1.925 train accuracy: 0.812
# [41,   600/  625] train loss: 1.172 train accuracy: 0.938
# epoch: 41 validation accuracy: 0.799
# [42,   200/  625] train loss: 0.836 train accuracy: 0.750
# [42,   400/  625] train loss: 1.323 train accuracy: 0.938
# [42,   600/  625] train loss: 1.863 train accuracy: 0.938
# epoch: 42 validation accuracy: 0.799
# [43,   200/  625] train loss: 2.547 train accuracy: 0.875
# [43,   400/  625] train loss: 1.983 train accuracy: 0.875
# [43,   600/  625] train loss: 1.745 train accuracy: 0.875
# epoch: 43 validation accuracy: 0.801
# [44,   200/  625] train loss: 2.363 train accuracy: 0.812
# [44,   400/  625] train loss: 2.365 train accuracy: 0.812
# [44,   600/  625] train loss: 2.637 train accuracy: 0.750
# epoch: 44 validation accuracy: 0.799
# [45,   200/  625] train loss: 3.302 train accuracy: 0.688
# [45,   400/  625] train loss: 1.879 train accuracy: 0.875
# [45,   600/  625] train loss: 1.945 train accuracy: 0.875
# epoch: 45 validation accuracy: 0.799
# [46,   200/  625] train loss: 1.979 train accuracy: 0.938
# [46,   400/  625] train loss: 2.021 train accuracy: 0.688
# [46,   600/  625] train loss: 1.812 train accuracy: 0.875
# epoch: 46 validation accuracy: 0.799
# [47,   200/  625] train loss: 1.427 train accuracy: 0.938
# [47,   400/  625] train loss: 1.930 train accuracy: 0.812
# [47,   600/  625] train loss: 1.150 train accuracy: 0.938
# epoch: 47 validation accuracy: 0.799
# [48,   200/  625] train loss: 2.340 train accuracy: 0.875
# [48,   400/  625] train loss: 1.421 train accuracy: 0.875
# [48,   600/  625] train loss: 1.812 train accuracy: 0.875
# epoch: 48 validation accuracy: 0.798
# [49,   200/  625] train loss: 1.582 train accuracy: 0.875
# [49,   400/  625] train loss: 4.728 train accuracy: 0.750
# [49,   600/  625] train loss: 1.568 train accuracy: 0.938
# epoch: 49 validation accuracy: 0.800
# [50,   200/  625] train loss: 2.009 train accuracy: 0.875
# [50,   400/  625] train loss: 0.954 train accuracy: 0.938
# [50,   600/  625] train loss: 1.082 train accuracy: 0.875
# epoch: 50 validation accuracy: 0.798

# %%
torch.save(student_net.state_dict(), BASE_PATH+'/net_params_new.pkl')

# %%
_, test_accuracy = getLossAccuracyOnDataset(student_net, testloader, device)
print('teacher test accuracy (w distillation): ', test_accuracy)
# Out:
# teacher test accuracy (w distillation):  0.7983957219251336
